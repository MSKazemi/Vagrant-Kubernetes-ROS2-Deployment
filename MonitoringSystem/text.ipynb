# %%
import pandas as pd

dt = pd.read_csv("./prometheus_data.csv")
dt
# Out:
#       __name__     container       endpoint             instance  \
# 0           up  alertmanager       http-web       10.46.0.7:9093
# 1           up  alertmanager       http-web       10.46.0.7:9093
# 2           up  alertmanager       http-web       10.46.0.7:9093
# 3           up  alertmanager       http-web       10.46.0.7:9093
# 4           up  alertmanager       http-web       10.46.0.7:9093
# ...        ...           ...            ...                  ...
# 11008       up           NaN  https-metrics  192.168.56.12:10250
# 11009       up           NaN  https-metrics  192.168.56.12:10250
# 11010       up           NaN  https-metrics  192.168.56.12:10250
# 11011       up           NaN  https-metrics  192.168.56.12:10250
# 11012       up           NaN  https-metrics  192.168.56.12:10250
#
#                                            job    namespace  \
# 0      prometheus-kube-prometheus-alertmanager   prometheus
# 1      prometheus-kube-prometheus-alertmanager   prometheus
# 2      prometheus-kube-prometheus-alertmanager   prometheus
# 3      prometheus-kube-prometheus-alertmanager   prometheus
# 4      prometheus-kube-prometheus-alertmanager   prometheus
# ...                                        ...          ...
# 11008                                  kubelet  kube-system
# 11009                                  kubelet  kube-system
# 11010                                  kubelet  kube-system
# 11011                                  kubelet  kube-system
# 11012                                  kubelet  kube-system
#
#                                                      pod  \
# 0      alertmanager-prometheus-kube-prometheus-alertm...
# 1      alertmanager-prometheus-kube-prometheus-alertm...
# 2      alertmanager-prometheus-kube-prometheus-alertm...
# 3      alertmanager-prometheus-kube-prometheus-alertm...
# 4      alertmanager-prometheus-kube-prometheus-alertm...
# ...                                                  ...
# 11008                                                NaN
# 11009                                                NaN
# 11010                                                NaN
# 11011                                                NaN
# 11012                                                NaN
#
#                                        service            timestamp  value  \
# 0      prometheus-kube-prometheus-alertmanager  2024-04-17 10:51:34      1
# 1      prometheus-kube-prometheus-alertmanager  2024-04-17 10:51:49      1
# 2      prometheus-kube-prometheus-alertmanager  2024-04-17 10:52:04      1
# 3      prometheus-kube-prometheus-alertmanager  2024-04-17 10:52:19      1
# 4      prometheus-kube-prometheus-alertmanager  2024-04-17 10:52:34      1
# ...                                        ...                  ...    ...
# 11008       prometheus-kube-prometheus-kubelet  2024-04-17 12:44:04      1
# 11009       prometheus-kube-prometheus-kubelet  2024-04-17 12:44:19      1
# 11010       prometheus-kube-prometheus-kubelet  2024-04-17 12:44:34      1
# 11011       prometheus-kube-prometheus-kubelet  2024-04-17 12:44:49      1
# 11012       prometheus-kube-prometheus-kubelet  2024-04-17 12:45:04      1
#
#           metrics_path node
# 0                  NaN  NaN
# 1                  NaN  NaN
# 2                  NaN  NaN
# 3                  NaN  NaN
# 4                  NaN  NaN
# ...                ...  ...
# 11008  /metrics/probes   w2
# 11009  /metrics/probes   w2
# 11010  /metrics/probes   w2
# 11011  /metrics/probes   w2
# 11012  /metrics/probes   w2
#
# [11013 rows x 12 columns]

# %%
from prometheus_api_client import PrometheusConnect
# prom = PrometheusConnect(url ="http://localhost:9090", disable_ssl=True)
prom = PrometheusConnect(url ="http://192.168.56.10:30090", disable_ssl=True)
import datetime
from datetime import datetime, timedelta  
import pandas as pd

# %%
# !pip install prometheus-api-client
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/mohsen/venv/myenv/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/mohsen/venv/myenv/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /home/mohsen/venv/myenv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/mohsen/venv/myenv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mohsen/venv/myenv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/mohsen/venv/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Instant Query
result = prom.custom_query(query="node_cpu_seconds_total")
# print(result)
# Range Query
result_range = prom.custom_query_range(
    query="node_cpu_seconds_total",
    start_time= datetime.now() - timedelta(hours=2),
    end_time=datetime.now(),
    step='15s'
)
print(result_range)
# Out:
# [{'metric': {'__name__': 'node_cpu_seconds_total', 'container': 'node-exporter', 'cpu': '0', 'endpoint': 'http-metrics', 'instance': '192.168.56.10:9100', 'job': 'node-exporter', 'mode': 'idle', 'namespace': 'prometheus', 'pod': 'prometheus-prometheus-node-exporter-gh7qx', 'service': 'prometheus-prometheus-node-exporter'}, 'values': [[1713359613, '7359.27'], [1713359628, '7388.17'], [1713359643, '7388.17'], [1713359658, '7417.4'], [1713359673, '7417.4'], [1713359688, '7446.49'], [1713359703, '7446.49'], [1713359718, '7475.77'], [1713359733, '7475.77'], [1713359748, '7505.04'], [1713359763, '7505.04'], [1713359778, '7534.18'], [1713359793, '7534.18'], [1713359808, '7563.14'], [1713359823, '7563.14'], [1713359838, '7592.33'], [1713359853, '7592.33'], [1713359868, '7621.42'], [1713359883, '7621.42'], [1713359898, '7650.6'], [1713359913, '7650.6'], [1713359928, '7679.82'], [1713359943, '7679.82'], [1713359958, '7709.14'], [1713359973, '7709.14'], [1713359988, '7738.27'], [1713360003, '7738.27'], [1713360018, '7766.93'], [1713360033, '7766.93'], [1713360048, '7796.08'], [1713360063, '7796.08'], [1713360078, '7825.23'], [1713360093, '7825.23'], [1713360108, '7854.43'], [1713360123, '7854.43'], [1713360138, '7883.6'], [1713360153, '7883.6'], [1713360168, '7912.78'], [1713360183, '7912.78'], [1713360198, '7942.07'], [1713360213, '7942.07'], [1713360228, '7971.27'], [1713360243, '7971.27'], [1713360258, '8000.59'], [1713360273, '8000.59'], [1713360288, '8029.73'], [1713360303, '8029.73'], [1713360318, '8058.74'], [1713360333, '8058.74'], [1713360348, '8087.57'], [1713360363, '8087.57'], [1713360378, '8116.84'], [1713360393, '8116.84'], [1713360408, '8145.98'], [1713360423, '8145.98'], [1713360438, '8174.88'], [1713360453, '8174.88'], [1713360468, '8203.98'], [1713360483, '8203.98'], [1713360498, '8233.17'], [1713360513, '8233.17'], [1713360528, '8262.39'], [1713360543, '8262.39'], [1713360558, '8291.42'], [1713360573, '8291.42'], [1713360588, '8320.42'], [1713360603, '8320.42'], [1713360618, '8349.65'], [1713360633, '8349.65'], [1713360648, '8378.73'], [1713360663, '8378.73'], [1713360678, '8407.71'], [1713360693, '8407.71'], [1713360708, '8436.91'], [1713360723, '8436.91'], [1713360738, '8465.95'], [1713360753, '8465.95'], [1713360768, '8495'], [1713360783, '8495'], [1713360798, '8524.17'], [1713360813, '8524.17'], [1713360828, '8552.9'], [1713360843, '8552.9'], [1713360858, '8581.68'], [1713360873, '8581.68'], [1713360888, '8610.81'], [1713360903, '8610.81'], [1713360918, '8639.94'], [1713360933, '8639.94'], [1713360948, '8669.1'], [1713360963, '8669.1'], [1713360978, '8698.33'], [1713360993, '8698.33'], [1713361008, '8727.49'], [1713361023, '8727.49'], [1713361038, '8756.87'], [1713361053, '8756.87'], [1713361068, '8786.12'], [1713361083, '8786.12'], [1713361098, '8815.16'], [1713361113, '8815.16'], [1713361128, '8843.77'], [1713361143, '8843.77'], [1713361158, '8872.7'], [1713361173, '8872.7'], [1713361188, '8901.83'], [1713361203, '8901.83'], [1713361218, '8930.69'], [1713361233, '8930.69'], [1713361248, '8959.7'], [1713361263, '8959.7'], [1713361278, '8988.71'], [1713361293, '8988.71'], [1713361308, '9017.75'], [1713361323, '9017.75'], [1713361338, '9046.85'], [1713361353, '9046.85'], [1713361368, '9075.99'], [1713361383, '9075.99'], [1713361398, '9105.24'], [1713361413, '9105.24'], [1713361428, '9134.5'], [1713361443, '9134.5'], [1713361458, '9163.8'], [1713361473, '9163.8'], [1713361488, '9193.07'], [1713361503, '9193.07'], [1713361518, '9222.34'], [1713361533, '9222.34'], [1713361548, '9251.29'], [1713361563, '9251.29'], [1713361578, '9280.4'], [1713361593, '9280.4'], [1713361608, '9309.43'], [1713361623, '9309.43'], [1713361638, '9338.5'], [1713361653, '9338.5'], [1713361668, '9367.64'], [1713361683, '9367.64'], [1713361698, '9396.87'], [1713361713, '9396.87'], [1713361728, '9425.91'], [1713361743, '9425.91'], [1713361758, '9455.33'], [1713361773, '9455.33'], [1713361788, '9484.39'], [1713361803, '9484.39'], [1713361818, '951 ...

# %%
import json

# Assuming 'result_range' is your data loaded from Prometheus
# result_range = [...]  # This should be replaced with your actual data query from Prometheus

# Define the path to save the JSON file
file_path = 'prometheus_data_node_cpu_seconds_total.json'

# Save the data to a JSON file
with open(file_path, 'w') as json_file:
    json.dump(result_range, json_file, indent=4)

print(f"Data has been saved to {file_path}.")
# Out:
# Data has been saved to prometheus_data_node_cpu_seconds_total.json.

# %%
# result_range = prom.custom_query_range(
#     query='100 - (avg by (instance) (rate(node_cpu_seconds_total{mode="idle"}[1m])) * 100)',
#     start_time=datetime.now() - timedelta(hours=2),
#     end_time=datetime.now(),
#     step='15s'
# )
# print(result_range)

# Creating a list to hold data for DataFrame
data = []
for result in result_range:
    for value in result['values']:
        timestamp = value[0]
        metric_value = value[1]
        metric_info = result['metric']
        data.append({**metric_info, 'timestamp': datetime.fromtimestamp(float(timestamp)), 'value': metric_value})

# Convert list to DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('prometheus_data2.csv', index=False)

# Optional: Save to other formats
# Save to Excel
# df.to_excel('prometheus_data.xlsx', index=False)


# Display the DataFrame
# print(df.head())

# %%
from prometheus_api_client import PrometheusConnect

# Setup connection (ensure the URL is correct for your Prometheus server)
prom = PrometheusConnect(url ="http://192.168.56.10:30090", disable_ssl=True)

# prom = PrometheusConnect(url ="http://your-prometheus-server-url", disable_ssl=True)

# Fetch all metric names
all_metrics = prom.all_metrics()

# Print all metric names
print("Available Metrics:")
for metric in all_metrics:
    print(metric)
# Out:
# Available Metrics:
# :node_memory_MemAvailable_bytes:sum
# ALERTS
# ALERTS_FOR_STATE
# aggregator_discovery_aggregation_count_total
# aggregator_unavailable_apiservice
# alertmanager_alerts
# alertmanager_alerts_invalid_total
# alertmanager_alerts_received_total
# alertmanager_build_info
# alertmanager_cluster_enabled
# alertmanager_config_hash
# alertmanager_config_last_reload_success_timestamp_seconds
# alertmanager_config_last_reload_successful
# alertmanager_dispatcher_aggregation_groups
# alertmanager_dispatcher_alert_processing_duration_seconds_count
# alertmanager_dispatcher_alert_processing_duration_seconds_sum
# alertmanager_http_concurrency_limit_exceeded_total
# alertmanager_http_request_duration_seconds_bucket
# alertmanager_http_request_duration_seconds_count
# alertmanager_http_request_duration_seconds_sum
# alertmanager_http_requests_in_flight
# alertmanager_http_response_size_bytes_bucket
# alertmanager_http_response_size_bytes_count
# alertmanager_http_response_size_bytes_sum
# alertmanager_inhibition_rules
# alertmanager_integrations
# alertmanager_marked_alerts
# alertmanager_nflog_gc_duration_seconds_count
# alertmanager_nflog_gc_duration_seconds_sum
# alertmanager_nflog_gossip_messages_propagated_total
# alertmanager_nflog_maintenance_errors_total
# alertmanager_nflog_maintenance_total
# alertmanager_nflog_queries_total
# alertmanager_nflog_query_duration_seconds_bucket
# alertmanager_nflog_query_duration_seconds_count
# alertmanager_nflog_query_duration_seconds_sum
# alertmanager_nflog_query_errors_total
# alertmanager_nflog_snapshot_duration_seconds_count
# alertmanager_nflog_snapshot_duration_seconds_sum
# alertmanager_nflog_snapshot_size_bytes
# alertmanager_notification_latency_seconds_bucket
# alertmanager_notification_latency_seconds_count
# alertmanager_notification_latency_seconds_sum
# alertmanager_notification_requests_failed_total
# alertmanager_notification_requests_total
# alertmanager_notifications_failed_total
# alertmanager_notifications_total
# alertmanager_receivers
# alertmanager_silences
# alertmanager_silences_gc_duration_seconds_count
# alertmanager_silences_gc_duration_seconds_sum
# alertmanager_silences_gossip_messages_propagated_total
# alertmanager_silences_maintenance_errors_total
# alertmanager_silences_maintenance_total
# alertmanager_silences_queries_total
# alertmanager_silences_query_duration_seconds_bucket
# alertmanager_silences_query_duration_seconds_count
# alertmanager_silences_query_duration_seconds_sum
# alertmanager_silences_query_errors_total
# alertmanager_silences_snapshot_duration_seconds_count
# alertmanager_silences_snapshot_duration_seconds_sum
# alertmanager_silences_snapshot_size_bytes
# apiextensions_apiserver_validation_ratcheting_seconds_bucket
# apiextensions_apiserver_validation_ratcheting_seconds_count
# apiextensions_apiserver_validation_ratcheting_seconds_sum
# apiextensions_openapi_v2_regeneration_count
# apiextensions_openapi_v3_regeneration_count
# apiserver_admission_controller_admission_duration_seconds_bucket
# apiserver_admission_controller_admission_duration_seconds_count
# apiserver_admission_controller_admission_duration_seconds_sum
# apiserver_admission_step_admission_duration_seconds_bucket
# apiserver_admission_step_admission_duration_seconds_count
# apiserver_admission_step_admission_duration_seconds_sum
# apiserver_admission_step_admission_duration_seconds_summary
# apiserver_admission_step_admission_duration_seconds_summary_count
# apiserver_admission_step_admission_duration_seconds_summary_sum
# apiserver_admission_webhook_admission_duration_seconds_bucket
# apiserver_admission_webhook_admission_duration_seconds_count
# apiserver_admission_webhook_admission_duration_seconds_sum
# apiserver_admission_webhook_fail_open_count
# apiserver_admission_webhook_request_total
# apiserver_audit_event_total
# apiserver_audit_requests_rejected_total
# apiserver_cache_list_fetched_objects_total
# apiserver_cache_list_returned_objects_total
# apiserver_cache_list_total
# apiserver_cel_compilation_duration_seconds_bucket
# apiserver_cel_compilation_duration_seconds_count
# apiserver_cel_compilation_duration_seconds_sum
# apiserver_cel_evaluation_duration_seconds_bucket
# apiserver_cel_evaluation_duration_seconds_count
# apiserver_cel_evaluation_duration_seconds_sum
# apiserver_client_certificate_expiration_seconds_bucket
# apiserver_client_certificate_expiration_seconds_count
# apiserver_client_certificate_expiration_seconds_sum
# apiserver_clusterip_repair_reconcile_errors_total
# apiserver_current_inflight_requests
# apiserver_current_inqueue_requests
# apiserver_delegated_authn_request_duration_seconds_bucket
# apiserver_delegated_authn_request_duration_seconds_count
# apiserver_delegated_authn_request_duration_seconds_sum
# apiserver_delegated_authn_request_total
# apiserver_delegated_authz_request_duration_seconds_bucket
# apiserver_delegated_authz_request_duration_seconds_count
# apiserver_delegated_authz_request_duration_seconds_sum
# apiserver_delegated_authz_request_total
# apiserver_envelope_encryption_dek_cache_fill_percent
# apiserver_flowcontrol_current_executing_requests
# apiserver_flowcontrol_current_executing_seats
# apiserver_flowcontrol_current_inqueue_requests
# apiserver_flowcontrol_current_inqueue_seats
# apiserver_flowcontrol_current_limit_seats
# apiserver_flowcontrol_current_r
# apiserver_flowcontrol_demand_seats_average
# apiserver_flowcontrol_demand_seats_bucket
# apiserver_flowcontrol_demand_seats_count
# apiserver_flowcontrol_demand_seats_high_watermark
# apiserver_flowcontrol_demand_seats_smoothed
# apiserver_flowcontrol_demand_seats_stdev
# apiserver_flowcontrol_demand_seats_sum
# apiserver_flowcontrol_dispatch_r
# apiserver_flowcontrol_dispatched_requests_total
# apiserver_flowcontrol_latest_s
# apiserver_flowcontrol_lower_limit_seats
# apiserver_flowcontrol_next_discounted_s_bounds
# apiserver_flowcontrol_next_s_bounds
# apiserver_flowcontrol_nominal_limit_seats
# apiserver_flowcontrol_priority_level_request_utilization_bucket
# apiserver_flowcontrol_priority_level_request_utilization_count
# apiserver_flowcontrol_priority_level_request_utilization_sum
# apiserver_flowcontrol_priority_level_seat_utilization_bucket
# apiserver_flowcontrol_priority_level_seat_utilization_count
# apiserver_flowcontrol_priority_level_seat_utilization_sum
# apiserver_flowcontrol_read_vs_write_current_requests_bucket
# apiserver_flowcontrol_read_vs_write_current_requests_count
# apiserver_flowcontrol_read_vs_write_current_requests_sum
# apiserver_flowcontrol_request_concurrency_in_use
# apiserver_flowcontrol_request_concurrency_limit
# apiserver_flowcontrol_request_execution_seconds_bucket
# apiserver_flowcontrol_request_execution_seconds_count
# apiserver_flowcontrol_request_execution_seconds_sum
# apiserver_flowcontrol_request_queue_length_after_enqueue_bucket
# apiserver_flowcontrol_request_queue_length_after_enqueue_count
# apiserver_flowcontrol_request_queue_length_after_enqueue_sum
# apiserver_flowcontrol_request_wait_duration_seconds_bucket
# apiserver_flowcontrol_request_wait_duration_seconds_count
# apiserver_flowcontrol_request_wait_duration_seconds_sum
# apiserver_flowcontrol_seat_fair_frac
# apiserver_flowcontrol_target_seats
# apiserver_flowcontrol_upper_limit_seats
# apiserver_flowcontrol_watch_count_samples_bucket
# apiserver_flowcontrol_watch_count_samples_count
# apiserver_flowcontrol_watch_count_samples_sum
# apiserver_flowcontrol_work_estimated_seats_bucket
# apiserver_flowcontrol_work_estimated_seats_count
# apiserver_flowcontrol_work_estimated_seats_sum
# apiserver_init_events_total
# apiserver_kube_aggregator_x509_insecure_sha1_total
# apiserver_kube_aggregator_x509_missing_san_total
# apiserver_longrunning_requests
# apiserver_nodeport_repair_reconcile_errors_total
# apiserver_request:availability30d
# apiserver_request:burnrate1d
# apiserver_request:burnrate1h
# apiserver_request:burnrate2h
# apiserver_request:burnrate30m
# apiserver_request:burnrate3d
# apiserver_request:burnrate5m
# apiserver_request:burnrate6h
# apiserver_request_body_size_bytes_bucket
# apiserver_request_body_size_bytes_count
# apiserver_request_body_size_bytes_sum
# apiserver_request_duration_seconds_bucket
# apiserver_request_duration_seconds_count
# apiserver_request_duration_seconds_sum
# apiserver_request_filter_duration_seconds_bucket
# apiserver_request_filter_duration_seconds_count
# apiserver_request_filter_duration_seconds_sum
# apiserver_request_post_timeout_total
# apiserver_request_sli_duration_seconds_bucket
# apiserver_request_sli_duration_seconds_count
# apiserver_request_sli_duration_seconds_sum
# apiserver_request_terminations_total
# apiserver_request_timestamp_comparison_time_bucket
# apiserver_request_timestamp_comparison_time_count
# apiserver_request_timestamp_comparison_time_sum
# apiserver_request_total
# apiserver_response_sizes_bucket
# apiserver_response_sizes_count
# apiserver_response_sizes_sum
# apiserver_selfrequest_total
# apiserver_storage_data_key_generation_duration_seconds_bucket
# apiserver_storage_data_key_generation_duration_seconds_count
# apiserver_storage_data_key_generation_duration_seconds_sum
# apiserver_storage_data_key_generation_failures_total
# apiserver_storage_envelope_transformation_cache_misses_total
# apiserver_storage_list_evaluated_objects_total
# apiserver_storage_list_fetched_objects_total
# apiserver_storage_list_returned_objects_total
# apiserver_storage_list_total
# apiserver_storage_objects
# apiserver_storage_size_bytes
# apiserver_tls_handshake_errors_total
# apiserver_watch_cache_events_dispatched_total
# apiserver_watch_cache_events_received_total
# apiserver_watch_cache_initializations_total
# apiserver_watch_events_sizes_bucket
# apiserver_watch_events_sizes_count
# apiserver_watch_events_sizes_sum
# apiserver_watch_events_total
# apiserver_webhooks_x509_insecure_sha1_total
# apiserver_webhooks_x509_missing_san_total
# authenticated_user_requests
# authentication_attempts
# authentication_duration_seconds_bucket
# authentication_duration_seconds_count
# authentication_duration_seconds_sum
# authentication_token_cache_active_fetch_count
# authentication_token_cache_fetch_total
# authentication_token_cache_request_duration_seconds_bucket
# authentication_token_cache_request_duration_seconds_count
# authentication_token_cache_request_duration_seconds_sum
# authentication_token_cache_request_total
# authorization_attempts_total
# authorization_duration_seconds_bucket
# authorization_duration_seconds_count
# authorization_duration_seconds_sum
# cadvisor_version_info
# cardinality_enforcement_unexpected_categorizations_total
# cluster:namespace:pod_cpu:active:kube_pod_container_resource_requests
# cluster:namespace:pod_memory:active:kube_pod_container_resource_limits
# cluster:namespace:pod_memory:active:kube_pod_container_resource_requests
# cluster:node_cpu:ratio
# cluster:node_cpu:ratio_rate5m
# cluster:node_cpu:sum_rate5m
# cluster_quantile:apiserver_request_sli_duration_seconds:histogram_quantile
# cluster_verb_scope:apiserver_request_sli_duration_seconds_count:increase1h
# cluster_verb_scope:apiserver_request_sli_duration_seconds_count:increase30d
# cluster_verb_scope_le:apiserver_request_sli_duration_seconds_bucket:increase1h
# cluster_verb_scope_le:apiserver_request_sli_duration_seconds_bucket:increase30d
# code:apiserver_request_total:increase30d
# code_resource:apiserver_request_total:rate5m
# code_verb:apiserver_request_total:increase1h
# code_verb:apiserver_request_total:increase30d
# container_blkio_device_usage_total
# container_cpu_usage_seconds_total
# container_fs_reads_bytes_total
# container_fs_reads_total
# container_fs_writes_bytes_total
# container_fs_writes_total
# container_last_seen
# container_memory_cache
# container_memory_failcnt
# container_memory_failures_total
# container_memory_kernel_usage
# container_memory_max_usage_bytes
# container_memory_rss
# container_memory_usage_bytes
# container_memory_working_set_bytes
# container_network_receive_bytes_total
# container_network_receive_errors_total
# container_network_receive_packets_dropped_total
# container_network_receive_packets_total
# container_network_transmit_bytes_total
# container_network_transmit_errors_total
# container_network_transmit_packets_dropped_total
# container_network_transmit_packets_total
# container_oom_events_total
# container_processes
# container_scrape_error
# container_sockets
# container_start_time_seconds
# container_threads
# container_ulimits_soft
# coredns_build_info
# coredns_cache_entries
# coredns_cache_hits_total
# coredns_cache_misses_total
# coredns_cache_requests_total
# coredns_dns_request_duration_seconds_bucket
# coredns_dns_request_duration_seconds_count
# coredns_dns_request_duration_seconds_sum
# coredns_dns_request_size_bytes_bucket
# coredns_dns_request_size_bytes_count
# coredns_dns_request_size_bytes_sum
# coredns_dns_requests_total
# coredns_dns_response_size_bytes_bucket
# coredns_dns_response_size_bytes_count
# coredns_dns_response_size_bytes_sum
# coredns_dns_responses_total
# coredns_forward_healthcheck_broken_total
# coredns_forward_max_concurrent_rejects_total
# coredns_health_request_duration_seconds_bucket
# coredns_health_request_duration_seconds_count
# coredns_health_request_duration_seconds_sum
# coredns_health_request_failures_total
# coredns_hosts_reload_timestamp_seconds
# coredns_kubernetes_dns_programming_duration_seconds_bucket
# coredns_kubernetes_dns_programming_duration_seconds_count
# coredns_kubernetes_dns_programming_duration_seconds_sum
# coredns_kubernetes_rest_client_rate_limiter_duration_seconds_bucket
# coredns_kubernetes_rest_client_rate_limiter_duration_seconds_count
# coredns_kubernetes_rest_client_rate_limiter_duration_seconds_sum
# coredns_kubernetes_rest_client_request_duration_seconds_bucket
# coredns_kubernetes_rest_client_request_duration_seconds_count
# coredns_kubernetes_rest_client_request_duration_seconds_sum
# coredns_kubernetes_rest_client_requests_total
# coredns_local_localhost_requests_total
# coredns_panics_total
# coredns_plugin_enabled
# coredns_proxy_conn_cache_hits_total
# coredns_proxy_conn_cache_misses_total
# coredns_proxy_request_duration_seconds_bucket
# coredns_proxy_request_duration_seconds_count
# coredns_proxy_request_duration_seconds_sum
# coredns_reload_failed_total
# count:up0
# count:up1
# disabled_metrics_total
# etcd_bookmark_counts
# etcd_lease_object_counts_bucket
# etcd_lease_object_counts_count
# etcd_lease_object_counts_sum
# etcd_request_duration_seconds_bucket
# etcd_request_duration_seconds_count
# etcd_request_duration_seconds_sum
# etcd_request_errors_total
# etcd_requests_total
# field_validation_request_duration_seconds_bucket
# field_validation_request_duration_seconds_count
# field_validation_request_duration_seconds_sum
# force_cleaned_failed_volume_operation_errors_total
# force_cleaned_failed_volume_operations_total
# get_token_count
# get_token_fail_count
# go_cgo_go_to_c_calls_calls_total
# go_cpu_classes_gc_mark_assist_cpu_seconds_total
# go_cpu_classes_gc_mark_dedicated_cpu_seconds_total
# go_cpu_classes_gc_mark_idle_cpu_seconds_total
# go_cpu_classes_gc_pause_cpu_seconds_total
# go_cpu_classes_gc_total_cpu_seconds_total
# go_cpu_classes_idle_cpu_seconds_total
# go_cpu_classes_scavenge_assist_cpu_seconds_total
# go_cpu_classes_scavenge_background_cpu_seconds_total
# go_cpu_classes_scavenge_total_cpu_seconds_total
# go_cpu_classes_total_cpu_seconds_total
# go_cpu_classes_user_cpu_seconds_total
# go_gc_cycles_automatic_gc_cycles_total
# go_gc_cycles_forced_gc_cycles_total
# go_gc_cycles_total_gc_cycles_total
# go_gc_duration_seconds
# go_gc_duration_seconds_count
# go_gc_duration_seconds_sum
# go_gc_gogc_percent
# go_gc_gomemlimit_bytes
# go_gc_heap_allocs_by_size_bytes_bucket
# go_gc_heap_allocs_by_size_bytes_count
# go_gc_heap_allocs_by_size_bytes_sum
# go_gc_heap_allocs_bytes_total
# go_gc_heap_allocs_objects_total
# go_gc_heap_frees_by_size_bytes_bucket
# go_gc_heap_frees_by_size_bytes_count
# go_gc_heap_frees_by_size_bytes_sum
# go_gc_heap_frees_bytes_total
# go_gc_heap_frees_objects_total
# go_gc_heap_goal_bytes
# go_gc_heap_live_bytes
# go_gc_heap_objects_objects
# go_gc_heap_tiny_allocs_objects_total
# go_gc_limiter_last_enabled_gc_cycle
# go_gc_pauses_seconds_bucket
# go_gc_pauses_seconds_count
# go_gc_pauses_seconds_sum
# go_gc_scan_globals_bytes
# go_gc_scan_heap_bytes
# go_gc_scan_stack_bytes
# go_gc_scan_total_bytes
# go_gc_stack_starting_size_bytes
# go_godebug_non_default_behavior_execerrdot_events_total
# go_godebug_non_default_behavior_gocachehash_events_total
# go_godebug_non_default_behavior_gocachetest_events_total
# go_godebug_non_default_behavior_gocacheverify_events_total
# go_godebug_non_default_behavior_http2client_events_total
# go_godebug_non_default_behavior_http2server_events_total
# go_godebug_non_default_behavior_installgoroot_events_total
# go_godebug_non_default_behavior_jstmpllitinterp_events_total
# go_godebug_non_default_behavior_multipartmaxheaders_events_total
# go_godebug_non_default_behavior_multipartmaxparts_events_total
# go_godebug_non_default_behavior_multipathtcp_events_total
# go_godebug_non_default_behavior_panicnil_events_total
# go_godebug_non_default_behavior_randautoseed_events_total
# go_godebug_non_default_behavior_tarinsecurepath_events_total
# go_godebug_non_default_behavior_tlsmaxrsasize_events_total
# go_godebug_non_default_behavior_x509sha1_events_total
# go_godebug_non_default_behavior_x509usefallbackroots_events_total
# go_godebug_non_default_behavior_zipinsecurepath_events_total
# go_goroutines
# go_info
# go_memory_classes_heap_free_bytes
# go_memory_classes_heap_objects_bytes
# go_memory_classes_heap_released_bytes
# go_memory_classes_heap_stacks_bytes
# go_memory_classes_heap_unused_bytes
# go_memory_classes_metadata_mcache_free_bytes
# go_memory_classes_metadata_mcache_inuse_bytes
# go_memory_classes_metadata_mspan_free_bytes
# go_memory_classes_metadata_mspan_inuse_bytes
# go_memory_classes_metadata_other_bytes
# go_memory_classes_os_stacks_bytes
# go_memory_classes_other_bytes
# go_memory_classes_profiling_buckets_bytes
# go_memory_classes_total_bytes
# go_memstats_alloc_bytes
# go_memstats_alloc_bytes_total
# go_memstats_buck_hash_sys_bytes
# go_memstats_frees_total
# go_memstats_gc_sys_bytes
# go_memstats_heap_alloc_bytes
# go_memstats_heap_idle_bytes
# go_memstats_heap_inuse_bytes
# go_memstats_heap_objects
# go_memstats_heap_released_bytes
# go_memstats_heap_sys_bytes
# go_memstats_last_gc_time_seconds
# go_memstats_lookups_total
# go_memstats_mallocs_total
# go_memstats_mcache_inuse_bytes
# go_memstats_mcache_sys_bytes
# go_memstats_mspan_inuse_bytes
# go_memstats_mspan_sys_bytes
# go_memstats_next_gc_bytes
# go_memstats_other_sys_bytes
# go_memstats_stack_inuse_bytes
# go_memstats_stack_sys_bytes
# go_memstats_sys_bytes
# go_sched_gomaxprocs_threads
# go_sched_goroutines_goroutines
# go_sched_latencies_seconds_bucket
# go_sched_latencies_seconds_count
# go_sched_latencies_seconds_sum
# go_sync_mutex_wait_total_seconds_total
# go_threads
# grpc_client_handled_total
# grpc_client_msg_received_total
# grpc_client_msg_sent_total
# grpc_client_started_total
# hidden_metrics_total
# instance:node_cpu:rate:sum
# instance:node_cpu:ratio
# instance:node_cpu_utilisation:rate5m
# instance:node_load1_per_cpu:ratio
# instance:node_memory_utilisation:ratio
# instance:node_network_receive_bytes:rate:sum
# instance:node_network_receive_bytes_excluding_lo:rate5m
# instance:node_network_receive_drop_excluding_lo:rate5m
# instance:node_network_transmit_bytes:rate:sum
# instance:node_network_transmit_bytes_excluding_lo:rate5m
# instance:node_network_transmit_drop_excluding_lo:rate5m
# instance:node_num_cpu:sum
# instance:node_vmstat_pgmajfault:rate5m
# instance_device:node_disk_io_time_seconds:rate5m
# instance_device:node_disk_io_time_weighted_seconds:rate5m
# kube_apiserver_clusterip_allocator_allocated_ips
# kube_apiserver_clusterip_allocator_allocation_total
# kube_apiserver_clusterip_allocator_available_ips
# kube_apiserver_nodeport_allocator_allocated_ports
# kube_apiserver_nodeport_allocator_allocation_total
# kube_apiserver_nodeport_allocator_available_ports
# kube_apiserver_pod_logs_backend_tls_failure_total
# kube_apiserver_pod_logs_insecure_backend_total
# kube_configmap_created
# kube_configmap_info
# kube_configmap_metadata_resource_version
# kube_daemonset_created
# kube_daemonset_metadata_generation
# kube_daemonset_status_current_number_scheduled
# kube_daemonset_status_desired_number_scheduled
# kube_daemonset_status_number_available
# kube_daemonset_status_number_misscheduled
# kube_daemonset_status_number_ready
# kube_daemonset_status_number_unavailable
# kube_daemonset_status_observed_generation
# kube_daemonset_status_updated_number_scheduled
# kube_deployment_created
# kube_deployment_metadata_generation
# kube_deployment_spec_paused
# kube_deployment_spec_replicas
# kube_deployment_spec_strategy_rollingupdate_max_surge
# kube_deployment_spec_strategy_rollingupdate_max_unavailable
# kube_deployment_status_condition
# kube_deployment_status_observed_generation
# kube_deployment_status_replicas
# kube_deployment_status_replicas_available
# kube_deployment_status_replicas_ready
# kube_deployment_status_replicas_unavailable
# kube_deployment_status_replicas_updated
# kube_endpoint_address
# kube_endpoint_address_available
# kube_endpoint_address_not_ready
# kube_endpoint_created
# kube_endpoint_info
# kube_endpoint_ports
# kube_lease_owner
# kube_lease_renew_time
# kube_mutatingwebhookconfiguration_created
# kube_mutatingwebhookconfiguration_info
# kube_mutatingwebhookconfiguration_metadata_resource_version
# kube_mutatingwebhookconfiguration_webhook_clientconfig_service
# kube_namespace_created
# kube_namespace_status_phase
# kube_node_created
# kube_node_info
# kube_node_role
# kube_node_spec_unschedulable
# kube_node_status_addresses
# kube_node_status_allocatable
# kube_node_status_capacity
# kube_node_status_condition
# kube_persistentvolume_capacity_bytes
# kube_persistentvolume_claim_ref
# kube_persistentvolume_created
# kube_persistentvolume_info
# kube_persistentvolume_status_phase
# kube_persistentvolumeclaim_access_mode
# kube_persistentvolumeclaim_created
# kube_persistentvolumeclaim_info
# kube_persistentvolumeclaim_resource_requests_storage_bytes
# kube_persistentvolumeclaim_status_phase
# kube_pod_completion_time
# kube_pod_container_info
# kube_pod_container_resource_limits
# kube_pod_container_resource_requests
# kube_pod_container_state_started
# kube_pod_container_status_last_terminated_exitcode
# kube_pod_container_status_last_terminated_reason
# kube_pod_container_status_last_terminated_timestamp
# kube_pod_container_status_ready
# kube_pod_container_status_restarts_total
# kube_pod_container_status_running
# kube_pod_container_status_terminated
# kube_pod_container_status_terminated_reason
# kube_pod_container_status_waiting
# kube_pod_container_status_waiting_reason
# kube_pod_created
# kube_pod_info
# kube_pod_init_container_info
# kube_pod_init_container_status_ready
# kube_pod_init_container_status_restarts_total
# kube_pod_init_container_status_running
# kube_pod_init_container_status_terminated
# kube_pod_init_container_status_terminated_reason
# kube_pod_init_container_status_waiting
# kube_pod_init_container_status_waiting_reason
# kube_pod_ips
# kube_pod_owner
# kube_pod_restart_policy
# kube_pod_scheduler
# kube_pod_service_account
# kube_pod_spec_volumes_persistentvolumeclaims_info
# kube_pod_spec_volumes_persistentvolumeclaims_readonly
# kube_pod_start_time
# kube_pod_status_container_ready_time
# kube_pod_status_initialized_time
# kube_pod_status_phase
# kube_pod_status_qos_class
# kube_pod_status_ready
# kube_pod_status_ready_time
# kube_pod_status_reason
# kube_pod_status_scheduled
# kube_pod_status_scheduled_time
# kube_pod_tolerations
# kube_replicaset_created
# kube_replicaset_metadata_generation
# kube_replicaset_owner
# kube_replicaset_spec_replicas
# kube_replicaset_status_fully_labeled_replicas
# kube_replicaset_status_observed_generation
# kube_replicaset_status_ready_replicas
# kube_replicaset_status_replicas
# kube_secret_created
# kube_secret_info
# kube_secret_metadata_resource_version
# kube_secret_owner
# kube_secret_type
# kube_service_created
# kube_service_info
# kube_service_spec_type
# kube_statefulset_created
# kube_statefulset_metadata_generation
# kube_statefulset_persistentvolumeclaim_retention_policy
# kube_statefulset_replicas
# kube_statefulset_status_current_revision
# kube_statefulset_status_observed_generation
# kube_statefulset_status_replicas
# kube_statefulset_status_replicas_available
# kube_statefulset_status_replicas_current
# kube_statefulset_status_replicas_ready
# kube_statefulset_status_replicas_updated
# kube_statefulset_status_update_revision
# kube_storageclass_created
# kube_storageclass_info
# kube_validatingwebhookconfiguration_created
# kube_validatingwebhookconfiguration_info
# kube_validatingwebhookconfiguration_metadata_resource_version
# kube_validatingwebhookconfiguration_webhook_clientconfig_service
# kubelet_active_pods
# kubelet_certificate_manager_client_expiration_renew_errors
# kubelet_certificate_manager_client_ttl_seconds
# kubelet_cgroup_manager_duration_seconds_bucket
# kubelet_cgroup_manager_duration_seconds_count
# kubelet_cgroup_manager_duration_seconds_sum
# kubelet_container_log_filesystem_used_bytes
# kubelet_containers_per_pod_count_bucket
# kubelet_containers_per_pod_count_count
# kubelet_containers_per_pod_count_sum
# kubelet_cpu_manager_pinning_errors_total
# kubelet_cpu_manager_pinning_requests_total
# kubelet_desired_pods
# kubelet_evented_pleg_connection_error_count
# kubelet_evented_pleg_connection_latency_seconds_bucket
# kubelet_evented_pleg_connection_latency_seconds_count
# kubelet_evented_pleg_connection_latency_seconds_sum
# kubelet_evented_pleg_connection_success_count
# kubelet_graceful_shutdown_end_time_seconds
# kubelet_graceful_shutdown_start_time_seconds
# kubelet_http_inflight_requests
# kubelet_http_requests_duration_seconds_bucket
# kubelet_http_requests_duration_seconds_count
# kubelet_http_requests_duration_seconds_sum
# kubelet_http_requests_total
# kubelet_lifecycle_handler_http_fallbacks_total
# kubelet_managed_ephemeral_containers
# kubelet_mirror_pods
# kubelet_node_name
# kubelet_node_startup_duration_seconds
# kubelet_node_startup_post_registration_duration_seconds
# kubelet_node_startup_pre_kubelet_duration_seconds
# kubelet_node_startup_pre_registration_duration_seconds
# kubelet_node_startup_registration_duration_seconds
# kubelet_orphan_pod_cleaned_volumes
# kubelet_orphan_pod_cleaned_volumes_errors
# kubelet_orphaned_runtime_pods_total
# kubelet_pleg_discard_events
# kubelet_pleg_last_seen_seconds
# kubelet_pleg_relist_duration_seconds_bucket
# kubelet_pleg_relist_duration_seconds_count
# kubelet_pleg_relist_duration_seconds_sum
# kubelet_pleg_relist_interval_seconds_bucket
# kubelet_pleg_relist_interval_seconds_count
# kubelet_pleg_relist_interval_seconds_sum
# kubelet_pod_start_duration_seconds_bucket
# kubelet_pod_start_duration_seconds_count
# kubelet_pod_start_duration_seconds_sum
# kubelet_pod_start_sli_duration_seconds_bucket
# kubelet_pod_start_sli_duration_seconds_count
# kubelet_pod_start_sli_duration_seconds_sum
# kubelet_pod_start_total_duration_seconds_bucket
# kubelet_pod_start_total_duration_seconds_count
# kubelet_pod_start_total_duration_seconds_sum
# kubelet_pod_status_sync_duration_seconds_bucket
# kubelet_pod_status_sync_duration_seconds_count
# kubelet_pod_status_sync_duration_seconds_sum
# kubelet_pod_worker_duration_seconds_bucket
# kubelet_pod_worker_duration_seconds_count
# kubelet_pod_worker_duration_seconds_sum
# kubelet_pod_worker_start_duration_seconds_bucket
# kubelet_pod_worker_start_duration_seconds_count
# kubelet_pod_worker_start_duration_seconds_sum
# kubelet_restarted_pods_total
# kubelet_run_podsandbox_duration_seconds_bucket
# kubelet_run_podsandbox_duration_seconds_count
# kubelet_run_podsandbox_duration_seconds_sum
# kubelet_run_podsandbox_errors_total
# kubelet_running_containers
# kubelet_running_pods
# kubelet_runtime_operations_duration_seconds_bucket
# kubelet_runtime_operations_duration_seconds_count
# kubelet_runtime_operations_duration_seconds_sum
# kubelet_runtime_operations_errors_total
# kubelet_runtime_operations_total
# kubelet_started_containers_total
# kubelet_started_pods_errors_total
# kubelet_started_pods_total
# kubelet_topology_manager_admission_duration_ms_bucket
# kubelet_topology_manager_admission_duration_ms_count
# kubelet_topology_manager_admission_duration_ms_sum
# kubelet_topology_manager_admission_errors_total
# kubelet_topology_manager_admission_requests_total
# kubelet_volume_metric_collection_duration_seconds_bucket
# kubelet_volume_metric_collection_duration_seconds_count
# kubelet_volume_metric_collection_duration_seconds_sum
# kubelet_volume_stats_available_bytes
# kubelet_volume_stats_capacity_bytes
# kubelet_volume_stats_inodes
# kubelet_volume_stats_inodes_free
# kubelet_volume_stats_inodes_used
# kubelet_volume_stats_used_bytes
# kubelet_working_pods
# kubernetes_build_info
# kubernetes_feature_enabled
# machine_cpu_cores
# machine_cpu_physical_cores
# machine_cpu_sockets
# machine_memory_bytes
# machine_nvm_avg_power_budget_watts
# machine_nvm_capacity
# machine_scrape_error
# machine_swap_bytes
# namespace_cpu:kube_pod_container_resource_requests:sum
# namespace_memory:kube_pod_container_resource_limits:sum
# namespace_memory:kube_pod_container_resource_requests:sum
# namespace_workload_pod:kube_pod_owner:relabel
# net_conntrack_dialer_conn_attempted_total
# net_conntrack_dialer_conn_closed_total
# net_conntrack_dialer_conn_established_total
# net_conntrack_dialer_conn_failed_total
# net_conntrack_listener_conn_accepted_total
# net_conntrack_listener_conn_closed_total
# node:node_cpu_utilization:ratio_rate5m
# node:node_num_cpu:sum
# node_arp_entries
# node_authorizer_graph_actions_duration_seconds_bucket
# node_authorizer_graph_actions_duration_seconds_count
# node_authorizer_graph_actions_duration_seconds_sum
# node_boot_time_seconds
# node_context_switches_total
# node_cooling_device_cur_state
# node_cooling_device_max_state
# node_cpu_guest_seconds_total
# node_cpu_seconds_total
# node_disk_discard_time_seconds_total
# node_disk_discarded_sectors_total
# node_disk_discards_completed_total
# node_disk_discards_merged_total
# node_disk_filesystem_info
# node_disk_flush_requests_time_seconds_total
# node_disk_flush_requests_total
# node_disk_info
# node_disk_io_now
# node_disk_io_time_seconds_total
# node_disk_io_time_weighted_seconds_total
# node_disk_read_bytes_total
# node_disk_read_time_seconds_total
# node_disk_reads_completed_total
# node_disk_reads_merged_total
# node_disk_write_time_seconds_total
# node_disk_writes_completed_total
# node_disk_writes_merged_total
# node_disk_written_bytes_total
# node_dmi_info
# node_entropy_available_bits
# node_entropy_pool_size_bits
# node_exporter_build_info
# node_filefd_allocated
# node_filefd_maximum
# node_filesystem_avail_bytes
# node_filesystem_device_error
# node_filesystem_files
# node_filesystem_files_free
# node_filesystem_free_bytes
# node_filesystem_readonly
# node_filesystem_size_bytes
# node_forks_total
# node_hwmon_chip_names
# node_hwmon_in_volts
# node_intr_total
# node_load1
# node_load15
# node_load5
# node_memory_Active_anon_bytes
# node_memory_Active_bytes
# node_memory_Active_file_bytes
# node_memory_AnonHugePages_bytes
# node_memory_AnonPages_bytes
# node_memory_Bounce_bytes
# node_memory_Buffers_bytes
# node_memory_Cached_bytes
# node_memory_CommitLimit_bytes
# node_memory_Committed_AS_bytes
# node_memory_DirectMap2M_bytes
# node_memory_DirectMap4k_bytes
# node_memory_Dirty_bytes
# node_memory_FileHugePages_bytes
# node_memory_FilePmdMapped_bytes
# node_memory_HardwareCorrupted_bytes
# node_memory_HugePages_Free
# node_memory_HugePages_Rsvd
# node_memory_HugePages_Surp
# node_memory_HugePages_Total
# node_memory_Hugepagesize_bytes
# node_memory_Hugetlb_bytes
# node_memory_Inactive_anon_bytes
# node_memory_Inactive_bytes
# node_memory_Inactive_file_bytes
# node_memory_KReclaimable_bytes
# node_memory_KernelStack_bytes
# node_memory_Mapped_bytes
# node_memory_MemAvailable_bytes
# node_memory_MemFree_bytes
# node_memory_MemTotal_bytes
# node_memory_Mlocked_bytes
# node_memory_NFS_Unstable_bytes
# node_memory_PageTables_bytes
# node_memory_Percpu_bytes
# node_memory_SReclaimable_bytes
# node_memory_SUnreclaim_bytes
# node_memory_ShmemHugePages_bytes
# node_memory_ShmemPmdMapped_bytes
# node_memory_Shmem_bytes
# node_memory_Slab_bytes
# node_memory_SwapCached_bytes
# node_memory_SwapFree_bytes
# node_memory_SwapTotal_bytes
# node_memory_Unevictable_bytes
# node_memory_VmallocChunk_bytes
# node_memory_VmallocTotal_bytes
# node_memory_VmallocUsed_bytes
# node_memory_WritebackTmp_bytes
# node_memory_Writeback_bytes
# node_namespace_pod:kube_pod_info:
# node_namespace_pod_container:container_cpu_usage_seconds_total:sum_irate
# node_namespace_pod_container:container_memory_cache
# node_namespace_pod_container:container_memory_rss
# node_namespace_pod_container:container_memory_working_set_bytes
# node_netstat_Icmp6_InErrors
# node_netstat_Icmp6_InMsgs
# node_netstat_Icmp6_OutMsgs
# node_netstat_Icmp_InErrors
# node_netstat_Icmp_InMsgs
# node_netstat_Icmp_OutMsgs
# node_netstat_Ip6_InOctets
# node_netstat_Ip6_OutOctets
# node_netstat_IpExt_InOctets
# node_netstat_IpExt_OutOctets
# node_netstat_Ip_Forwarding
# node_netstat_TcpExt_ListenDrops
# node_netstat_TcpExt_ListenOverflows
# node_netstat_TcpExt_SyncookiesFailed
# node_netstat_TcpExt_SyncookiesRecv
# node_netstat_TcpExt_SyncookiesSent
# node_netstat_TcpExt_TCPSynRetrans
# node_netstat_TcpExt_TCPTimeouts
# node_netstat_Tcp_ActiveOpens
# node_netstat_Tcp_CurrEstab
# node_netstat_Tcp_InErrs
# node_netstat_Tcp_InSegs
# node_netstat_Tcp_OutRsts
# node_netstat_Tcp_OutSegs
# node_netstat_Tcp_PassiveOpens
# node_netstat_Tcp_RetransSegs
# node_netstat_Udp6_InDatagrams
# node_netstat_Udp6_InErrors
# node_netstat_Udp6_NoPorts
# node_netstat_Udp6_OutDatagrams
# node_netstat_Udp6_RcvbufErrors
# node_netstat_Udp6_SndbufErrors
# node_netstat_UdpLite6_InErrors
# node_netstat_UdpLite_InErrors
# node_netstat_Udp_InDatagrams
# node_netstat_Udp_InErrors
# node_netstat_Udp_NoPorts
# node_netstat_Udp_OutDatagrams
# node_netstat_Udp_RcvbufErrors
# node_netstat_Udp_SndbufErrors
# node_network_address_assign_type
# node_network_carrier
# node_network_carrier_changes_total
# node_network_carrier_down_changes_total
# node_network_carrier_up_changes_total
# node_network_device_id
# node_network_dormant
# node_network_flags
# node_network_iface_id
# node_network_iface_link
# node_network_iface_link_mode
# node_network_info
# node_network_mtu_bytes
# node_network_name_assign_type
# node_network_net_dev_group
# node_network_protocol_type
# node_network_receive_bytes_total
# node_network_receive_compressed_total
# node_network_receive_drop_total
# node_network_receive_errs_total
# node_network_receive_fifo_total
# node_network_receive_frame_total
# node_network_receive_multicast_total
# node_network_receive_nohandler_total
# node_network_receive_packets_total
# node_network_speed_bytes
# node_network_transmit_bytes_total
# node_network_transmit_carrier_total
# node_network_transmit_colls_total
# node_network_transmit_compressed_total
# node_network_transmit_drop_total
# node_network_transmit_errs_total
# node_network_transmit_fifo_total
# node_network_transmit_packets_total
# node_network_transmit_queue_length
# node_network_up
# node_nf_conntrack_entries
# node_nf_conntrack_entries_limit
# node_os_info
# node_os_version
# node_power_supply_capacity
# node_power_supply_cyclecount
# node_power_supply_energy_full
# node_power_supply_energy_full_design
# node_power_supply_energy_watthour
# node_power_supply_info
# node_power_supply_online
# node_power_supply_power_watt
# node_power_supply_present
# node_power_supply_voltage_min_design
# node_power_supply_voltage_volt
# node_pressure_cpu_waiting_seconds_total
# node_pressure_io_stalled_seconds_total
# node_pressure_io_waiting_seconds_total
# node_pressure_memory_stalled_seconds_total
# node_pressure_memory_waiting_seconds_total
# node_procs_blocked
# node_procs_running
# node_quantile:kubelet_pleg_relist_duration_seconds:histogram_quantile
# node_schedstat_running_seconds_total
# node_schedstat_timeslices_total
# node_schedstat_waiting_seconds_total
# node_scrape_collector_duration_seconds
# node_scrape_collector_success
# node_selinux_enabled
# node_sockstat_FRAG6_inuse
# node_sockstat_FRAG6_memory
# node_sockstat_FRAG_inuse
# node_sockstat_FRAG_memory
# node_sockstat_RAW6_inuse
# node_sockstat_RAW_inuse
# node_sockstat_TCP6_inuse
# node_sockstat_TCP_alloc
# node_sockstat_TCP_inuse
# node_sockstat_TCP_mem
# node_sockstat_TCP_mem_bytes
# node_sockstat_TCP_orphan
# node_sockstat_TCP_tw
# node_sockstat_UDP6_inuse
# node_sockstat_UDPLITE6_inuse
# node_sockstat_UDPLITE_inuse
# node_sockstat_UDP_inuse
# node_sockstat_UDP_mem
# node_sockstat_UDP_mem_bytes
# node_sockstat_sockets_used
# node_softnet_backlog_len
# node_softnet_cpu_collision_total
# node_softnet_dropped_total
# node_softnet_flow_limit_count_total
# node_softnet_processed_total
# node_softnet_received_rps_total
# node_softnet_times_squeezed_total
# node_textfile_scrape_error
# node_time_clocksource_available_info
# node_time_clocksource_current_info
# node_time_seconds
# node_time_zone_offset_seconds
# node_timex_estimated_error_seconds
# node_timex_frequency_adjustment_ratio
# node_timex_loop_time_constant
# node_timex_maxerror_seconds
# node_timex_offset_seconds
# node_timex_pps_calibration_total
# node_timex_pps_error_total
# node_timex_pps_frequency_hertz
# node_timex_pps_jitter_seconds
# node_timex_pps_jitter_total
# node_timex_pps_shift_seconds
# node_timex_pps_stability_exceeded_total
# node_timex_pps_stability_hertz
# node_timex_status
# node_timex_sync_status
# node_timex_tai_offset_seconds
# node_timex_tick_seconds
# node_udp_queues
# node_uname_info
# node_vmstat_oom_kill
# node_vmstat_pgfault
# node_vmstat_pgmajfault
# node_vmstat_pgpgin
# node_vmstat_pgpgout
# node_vmstat_pswpin
# node_vmstat_pswpout
# pod_security_evaluations_total
# pod_security_exemptions_total
# prober_probe_duration_seconds_bucket
# prober_probe_duration_seconds_count
# prober_probe_duration_seconds_sum
# prober_probe_total
# process_cpu_seconds_total
# process_max_fds
# process_open_fds
# process_resident_memory_bytes
# process_start_time_seconds
# process_virtual_memory_bytes
# process_virtual_memory_max_bytes
# prometheus_api_remote_read_queries
# prometheus_build_info
# prometheus_config_last_reload_success_timestamp_seconds
# prometheus_config_last_reload_successful
# prometheus_engine_queries
# prometheus_engine_queries_concurrent_max
# prometheus_engine_query_duration_seconds
# prometheus_engine_query_duration_seconds_count
# prometheus_engine_query_duration_seconds_sum
# prometheus_engine_query_log_enabled
# prometheus_engine_query_log_failures_total
# prometheus_engine_query_samples_total
# prometheus_http_request_duration_seconds_bucket
# prometheus_http_request_duration_seconds_count
# prometheus_http_request_duration_seconds_sum
# prometheus_http_requests_total
# prometheus_http_response_size_bytes_bucket
# prometheus_http_response_size_bytes_count
# prometheus_http_response_size_bytes_sum
# prometheus_notifications_alertmanagers_discovered
# prometheus_notifications_dropped_total
# prometheus_notifications_errors_total
# prometheus_notifications_latency_seconds
# prometheus_notifications_latency_seconds_count
# prometheus_notifications_latency_seconds_sum
# prometheus_notifications_queue_capacity
# prometheus_notifications_queue_length
# prometheus_notifications_sent_total
# prometheus_operator_build_info
# prometheus_operator_list_operations_failed_total
# prometheus_operator_list_operations_total
# prometheus_operator_managed_resources
# prometheus_operator_node_address_lookup_errors_total
# prometheus_operator_node_syncs_failed_total
# prometheus_operator_node_syncs_total
# prometheus_operator_ready
# prometheus_operator_reconcile_duration_seconds_bucket
# prometheus_operator_reconcile_duration_seconds_count
# prometheus_operator_reconcile_duration_seconds_sum
# prometheus_operator_reconcile_errors_total
# prometheus_operator_reconcile_operations_total
# prometheus_operator_reconcile_sts_delete_create_total
# prometheus_operator_spec_replicas
# prometheus_operator_spec_shards
# prometheus_operator_status_update_errors_total
# prometheus_operator_status_update_operations_total
# prometheus_operator_syncs
# prometheus_operator_triggered_total
# prometheus_operator_watch_operations_failed_total
# prometheus_operator_watch_operations_total
# prometheus_ready
# prometheus_remote_storage_exemplars_in_total
# prometheus_remote_storage_highest_timestamp_in_seconds
# prometheus_remote_storage_histograms_in_total
# prometheus_remote_storage_samples_in_total
# prometheus_remote_storage_string_interner_zero_reference_releases_total
# prometheus_rule_evaluation_duration_seconds
# prometheus_rule_evaluation_duration_seconds_count
# prometheus_rule_evaluation_duration_seconds_sum
# prometheus_rule_evaluation_failures_total
# prometheus_rule_evaluations_total
# prometheus_rule_group_duration_seconds
# prometheus_rule_group_duration_seconds_count
# prometheus_rule_group_duration_seconds_sum
# prometheus_rule_group_interval_seconds
# prometheus_rule_group_iterations_missed_total
# prometheus_rule_group_iterations_total
# prometheus_rule_group_last_duration_seconds
# prometheus_rule_group_last_evaluation_samples
# prometheus_rule_group_last_evaluation_timestamp_seconds
# prometheus_rule_group_rules
# prometheus_sd_azure_cache_hit_total
# prometheus_sd_azure_failures_total
# prometheus_sd_consul_rpc_duration_seconds
# prometheus_sd_consul_rpc_duration_seconds_count
# prometheus_sd_consul_rpc_duration_seconds_sum
# prometheus_sd_consul_rpc_failures_total
# prometheus_sd_discovered_targets
# prometheus_sd_dns_lookup_failures_total
# prometheus_sd_dns_lookups_total
# prometheus_sd_failed_configs
# prometheus_sd_file_read_errors_total
# prometheus_sd_file_scan_duration_seconds
# prometheus_sd_file_scan_duration_seconds_count
# prometheus_sd_file_scan_duration_seconds_sum
# prometheus_sd_file_watcher_errors_total
# prometheus_sd_http_failures_total
# prometheus_sd_kubernetes_events_total
# prometheus_sd_kubernetes_http_request_duration_seconds_count
# prometheus_sd_kubernetes_http_request_duration_seconds_sum
# prometheus_sd_kubernetes_http_request_total
# prometheus_sd_kubernetes_workqueue_depth
# prometheus_sd_kubernetes_workqueue_items_total
# prometheus_sd_kubernetes_workqueue_latency_seconds_count
# prometheus_sd_kubernetes_workqueue_latency_seconds_sum
# prometheus_sd_kubernetes_workqueue_longest_running_processor_seconds
# prometheus_sd_kubernetes_workqueue_unfinished_work_seconds
# prometheus_sd_kubernetes_workqueue_work_duration_seconds_count
# prometheus_sd_kubernetes_workqueue_work_duration_seconds_sum
# prometheus_sd_kuma_fetch_duration_seconds
# prometheus_sd_kuma_fetch_duration_seconds_count
# prometheus_sd_kuma_fetch_duration_seconds_sum
# prometheus_sd_kuma_fetch_failures_total
# prometheus_sd_kuma_fetch_skipped_updates_total
# prometheus_sd_linode_failures_total
# prometheus_sd_nomad_failures_total
# prometheus_sd_received_updates_total
# prometheus_sd_updates_delayed_total
# prometheus_sd_updates_total
# prometheus_target_interval_length_seconds
# prometheus_target_interval_length_seconds_count
# prometheus_target_interval_length_seconds_sum
# prometheus_target_metadata_cache_bytes
# prometheus_target_metadata_cache_entries
# prometheus_target_scrape_pool_exceeded_label_limits_total
# prometheus_target_scrape_pool_exceeded_target_limit_total
# prometheus_target_scrape_pool_reloads_failed_total
# prometheus_target_scrape_pool_reloads_total
# prometheus_target_scrape_pool_sync_total
# prometheus_target_scrape_pool_target_limit
# prometheus_target_scrape_pool_targets
# prometheus_target_scrape_pools_failed_total
# prometheus_target_scrape_pools_total
# prometheus_target_scrapes_cache_flush_forced_total
# prometheus_target_scrapes_exceeded_body_size_limit_total
# prometheus_target_scrapes_exceeded_native_histogram_bucket_limit_total
# prometheus_target_scrapes_exceeded_sample_limit_total
# prometheus_target_scrapes_exemplar_out_of_order_total
# prometheus_target_scrapes_sample_duplicate_timestamp_total
# prometheus_target_scrapes_sample_out_of_bounds_total
# prometheus_target_scrapes_sample_out_of_order_total
# prometheus_target_sync_failed_total
# prometheus_target_sync_length_seconds
# prometheus_target_sync_length_seconds_count
# prometheus_target_sync_length_seconds_sum
# prometheus_template_text_expansion_failures_total
# prometheus_template_text_expansions_total
# prometheus_treecache_watcher_goroutines
# prometheus_treecache_zookeeper_failures_total
# prometheus_tsdb_blocks_loaded
# prometheus_tsdb_checkpoint_creations_failed_total
# prometheus_tsdb_checkpoint_creations_total
# prometheus_tsdb_checkpoint_deletions_failed_total
# prometheus_tsdb_checkpoint_deletions_total
# prometheus_tsdb_clean_start
# prometheus_tsdb_compaction_chunk_range_seconds_bucket
# prometheus_tsdb_compaction_chunk_range_seconds_count
# prometheus_tsdb_compaction_chunk_range_seconds_sum
# prometheus_tsdb_compaction_chunk_samples_bucket
# prometheus_tsdb_compaction_chunk_samples_count
# prometheus_tsdb_compaction_chunk_samples_sum
# prometheus_tsdb_compaction_chunk_size_bytes_bucket
# prometheus_tsdb_compaction_chunk_size_bytes_count
# prometheus_tsdb_compaction_chunk_size_bytes_sum
# prometheus_tsdb_compaction_duration_seconds_bucket
# prometheus_tsdb_compaction_duration_seconds_count
# prometheus_tsdb_compaction_duration_seconds_sum
# prometheus_tsdb_compaction_populating_block
# prometheus_tsdb_compactions_failed_total
# prometheus_tsdb_compactions_skipped_total
# prometheus_tsdb_compactions_total
# prometheus_tsdb_compactions_triggered_total
# prometheus_tsdb_data_replay_duration_seconds
# prometheus_tsdb_exemplar_exemplars_appended_total
# prometheus_tsdb_exemplar_exemplars_in_storage
# prometheus_tsdb_exemplar_last_exemplars_timestamp_seconds
# prometheus_tsdb_exemplar_max_exemplars
# prometheus_tsdb_exemplar_out_of_order_exemplars_total
# prometheus_tsdb_exemplar_series_with_exemplars_in_storage
# prometheus_tsdb_head_active_appenders
# prometheus_tsdb_head_chunks
# prometheus_tsdb_head_chunks_created_total
# prometheus_tsdb_head_chunks_removed_total
# prometheus_tsdb_head_chunks_storage_size_bytes
# prometheus_tsdb_head_gc_duration_seconds_count
# prometheus_tsdb_head_gc_duration_seconds_sum
# prometheus_tsdb_head_max_time
# prometheus_tsdb_head_max_time_seconds
# prometheus_tsdb_head_min_time
# prometheus_tsdb_head_min_time_seconds
# prometheus_tsdb_head_out_of_order_samples_appended_total
# prometheus_tsdb_head_samples_appended_total
# prometheus_tsdb_head_series
# prometheus_tsdb_head_series_created_total
# prometheus_tsdb_head_series_not_found_total
# prometheus_tsdb_head_series_removed_total
# prometheus_tsdb_head_truncations_failed_total
# prometheus_tsdb_head_truncations_total
# prometheus_tsdb_isolation_high_watermark
# prometheus_tsdb_isolation_low_watermark
# prometheus_tsdb_lowest_timestamp
# prometheus_tsdb_lowest_timestamp_seconds
# prometheus_tsdb_mmap_chunk_corruptions_total
# prometheus_tsdb_mmap_chunks_total
# prometheus_tsdb_out_of_bound_samples_total
# prometheus_tsdb_out_of_order_samples_total
# prometheus_tsdb_reloads_failures_total
# prometheus_tsdb_reloads_total
# prometheus_tsdb_retention_limit_bytes
# prometheus_tsdb_retention_limit_seconds
# prometheus_tsdb_size_retentions_total
# prometheus_tsdb_snapshot_replay_error_total
# prometheus_tsdb_storage_blocks_bytes
# prometheus_tsdb_symbol_table_size_bytes
# prometheus_tsdb_time_retentions_total
# prometheus_tsdb_tombstone_cleanup_seconds_bucket
# prometheus_tsdb_tombstone_cleanup_seconds_count
# prometheus_tsdb_tombstone_cleanup_seconds_sum
# prometheus_tsdb_too_old_samples_total
# prometheus_tsdb_vertical_compactions_total
# prometheus_tsdb_wal_completed_pages_total
# prometheus_tsdb_wal_corruptions_total
# prometheus_tsdb_wal_fsync_duration_seconds
# prometheus_tsdb_wal_fsync_duration_seconds_count
# prometheus_tsdb_wal_fsync_duration_seconds_sum
# prometheus_tsdb_wal_page_flushes_total
# prometheus_tsdb_wal_segment_current
# prometheus_tsdb_wal_storage_size_bytes
# prometheus_tsdb_wal_truncate_duration_seconds_count
# prometheus_tsdb_wal_truncate_duration_seconds_sum
# prometheus_tsdb_wal_truncations_failed_total
# prometheus_tsdb_wal_truncations_total
# prometheus_tsdb_wal_writes_failed_total
# prometheus_web_federation_errors_total
# prometheus_web_federation_warnings_total
# promhttp_metric_handler_errors_total
# promhttp_metric_handler_requests_in_flight
# promhttp_metric_handler_requests_total
# reconstruct_volume_operations_errors_total
# reconstruct_volume_operations_total
# registered_metrics_total
# reloader_config_apply_operations_failed_total
# reloader_config_apply_operations_total
# reloader_info
# reloader_last_reload_success_timestamp_seconds
# reloader_last_reload_successful
# reloader_reloads_failed_total
# reloader_reloads_total
# reloader_watch_errors_total
# reloader_watch_events_total
# reloader_watches
# rest_client_exec_plugin_certificate_rotation_age_bucket
# rest_client_exec_plugin_certificate_rotation_age_count
# rest_client_exec_plugin_certificate_rotation_age_sum
# rest_client_exec_plugin_ttl_seconds
# rest_client_rate_limiter_duration_seconds_bucket
# rest_client_rate_limiter_duration_seconds_count
# rest_client_rate_limiter_duration_seconds_sum
# rest_client_request_duration_seconds_bucket
# rest_client_request_duration_seconds_count
# rest_client_request_duration_seconds_sum
# rest_client_request_retries_total
# rest_client_request_size_bytes_bucket
# rest_client_request_size_bytes_count
# rest_client_request_size_bytes_sum
# rest_client_requests_total
# rest_client_response_size_bytes_bucket
# rest_client_response_size_bytes_count
# rest_client_response_size_bytes_sum
# rest_client_transport_cache_entries
# rest_client_transport_create_calls_total
# scrape_duration_seconds
# scrape_samples_post_metric_relabeling
# scrape_samples_scraped
# scrape_series_added
# serviceaccount_invalid_legacy_auto_token_uses_total
# serviceaccount_legacy_auto_token_uses_total
# serviceaccount_legacy_manual_token_uses_total
# serviceaccount_legacy_tokens_total
# serviceaccount_stale_tokens_total
# serviceaccount_valid_tokens_total
# storage_operation_duration_seconds_bucket
# storage_operation_duration_seconds_count
# storage_operation_duration_seconds_sum
# up
# volume_manager_selinux_container_errors_total
# volume_manager_selinux_container_warnings_total
# volume_manager_selinux_pod_context_mismatch_errors_total
# volume_manager_selinux_pod_context_mismatch_warnings_total
# volume_manager_total_volumes
# volume_operation_total_seconds_bucket
# volume_operation_total_seconds_count
# volume_operation_total_seconds_sum
# watch_cache_capacity
# watch_cache_capacity_increase_total
# workqueue_adds_total
# workqueue_depth
# workqueue_longest_running_processor_seconds
# workqueue_queue_duration_seconds_bucket
# workqueue_queue_duration_seconds_count
# workqueue_queue_duration_seconds_sum
# workqueue_retries_total
# workqueue_unfinished_work_seconds
# workqueue_work_duration_seconds_bucket
# workqueue_work_duration_seconds_count
# workqueue_work_duration_seconds_sum

# %%
from prometheus_api_client import PrometheusConnect

# Setup connection (ensure the URL is correct for your Prometheus server)
# prom = PrometheusConnect(url ="http://your-prometheus-server-url", disable_ssl=True)
prom = PrometheusConnect(url ="http://192.168.56.10:30090", disable_ssl=True)


# Fetch all metric names
all_metrics = prom.all_metrics()

# Define the file path where you want to save the metrics
file_path = 'prometheus_metrics.txt'

# Write all metrics to the text file, one per line
with open(file_path, 'w') as file:
    for metric in all_metrics:
        file.write(metric + '\n')

print(f"Metrics have been saved to {file_path}.")
# Out:
# Metrics have been saved to prometheus_metrics.txt.

# %%
import json
from prometheus_api_client import PrometheusConnect
from datetime import datetime, timedelta

# Setup connection
# prom = PrometheusConnect(url="http://your-prometheus-server-url", disable_ssl=True)
prom = PrometheusConnect(url ="http://192.168.56.10:30090", disable_ssl=True)


# Fetch all metric names
all_metrics = prom.all_metrics()

# Define a starting point for data collection (this might need adjustment)
# Here, it's arbitrarily set to 5 years ago. Adjust based on your actual data collection start.
start_time = datetime.now() - timedelta(days=5*365)

# Current time for the end of data collection
end_time = datetime.now()

# Step size for queries (e.g., "15m" for 15 minutes)
step = '15m'

for metric in all_metrics:
    # Perform a range query for each metric
    result_range = prom.custom_query_range(
        query=metric,
        start_time=start_time,
        end_time=end_time,
        step=step
    )

    # File to save the results
    file_path = f'{metric}.json'
    with open(file_path, 'w') as file:
        json.dump(result_range, file, indent=4)

    print(f"Data for {metric} has been saved to {file_path}.")

# %%
import json
import gzip
from prometheus_api_client import PrometheusConnect
from datetime import datetime, timedelta

# Setup connection
# prom = PrometheusConnect(url="http://your-prometheus-server-url", disable_ssl=True)
prom = PrometheusConnect(url ="http://192.168.56.10:30090", disable_ssl=True)

# Fetch all metric names
all_metrics = prom.all_metrics()

# Define a starting point for data collection
start_time = datetime.now() - timedelta(days=1)  # Example: 5 years ago
end_time = datetime.now()  # Current time
step = '15s'  # Step size

for metric in all_metrics:
    # Perform a range query for each metric
    result_range = prom.custom_query_range(
        query=metric,
        start_time=start_time,
        end_time=end_time,
        step=step
    )

    # Define file path with .gz extension
    file_path = f'./data/{metric.replace("/", "_")}.json.gz'  # Replace '/' with '_' to avoid path issues

    # Write data to a gzipped JSON file
    with gzip.open(file_path, 'wt', encoding='utf-8') as file:
        json.dump(result_range, file, indent=4)

    print(f"Data for {metric} has been saved to {file_path}.")
# Out:
# Data for :node_memory_MemAvailable_bytes:sum has been saved to ./data/:node_memory_MemAvailable_bytes:sum.json.gz.
# Data for ALERTS has been saved to ./data/ALERTS.json.gz.
# Data for ALERTS_FOR_STATE has been saved to ./data/ALERTS_FOR_STATE.json.gz.
# Data for aggregator_discovery_aggregation_count_total has been saved to ./data/aggregator_discovery_aggregation_count_total.json.gz.
# Data for aggregator_unavailable_apiservice has been saved to ./data/aggregator_unavailable_apiservice.json.gz.
# Data for alertmanager_alerts has been saved to ./data/alertmanager_alerts.json.gz.
# Data for alertmanager_alerts_invalid_total has been saved to ./data/alertmanager_alerts_invalid_total.json.gz.
# Data for alertmanager_alerts_received_total has been saved to ./data/alertmanager_alerts_received_total.json.gz.
# Data for alertmanager_build_info has been saved to ./data/alertmanager_build_info.json.gz.
# Data for alertmanager_cluster_enabled has been saved to ./data/alertmanager_cluster_enabled.json.gz.
# Data for alertmanager_config_hash has been saved to ./data/alertmanager_config_hash.json.gz.
# Data for alertmanager_config_last_reload_success_timestamp_seconds has been saved to ./data/alertmanager_config_last_reload_success_timestamp_seconds.json.gz.
# Data for alertmanager_config_last_reload_successful has been saved to ./data/alertmanager_config_last_reload_successful.json.gz.
# Data for alertmanager_dispatcher_aggregation_groups has been saved to ./data/alertmanager_dispatcher_aggregation_groups.json.gz.
# Data for alertmanager_dispatcher_alert_processing_duration_seconds_count has been saved to ./data/alertmanager_dispatcher_alert_processing_duration_seconds_count.json.gz.
# Data for alertmanager_dispatcher_alert_processing_duration_seconds_sum has been saved to ./data/alertmanager_dispatcher_alert_processing_duration_seconds_sum.json.gz.
# Data for alertmanager_http_concurrency_limit_exceeded_total has been saved to ./data/alertmanager_http_concurrency_limit_exceeded_total.json.gz.
# Data for alertmanager_http_request_duration_seconds_bucket has been saved to ./data/alertmanager_http_request_duration_seconds_bucket.json.gz.
# Data for alertmanager_http_request_duration_seconds_count has been saved to ./data/alertmanager_http_request_duration_seconds_count.json.gz.
# Data for alertmanager_http_request_duration_seconds_sum has been saved to ./data/alertmanager_http_request_duration_seconds_sum.json.gz.
# Data for alertmanager_http_requests_in_flight has been saved to ./data/alertmanager_http_requests_in_flight.json.gz.
# Data for alertmanager_http_response_size_bytes_bucket has been saved to ./data/alertmanager_http_response_size_bytes_bucket.json.gz.
# Data for alertmanager_http_response_size_bytes_count has been saved to ./data/alertmanager_http_response_size_bytes_count.json.gz.
# Data for alertmanager_http_response_size_bytes_sum has been saved to ./data/alertmanager_http_response_size_bytes_sum.json.gz.
# Data for alertmanager_inhibition_rules has been saved to ./data/alertmanager_inhibition_rules.json.gz.
# Data for alertmanager_integrations has been saved to ./data/alertmanager_integrations.json.gz.
# Data for alertmanager_marked_alerts has been saved to ./data/alertmanager_marked_alerts.json.gz.
# Data for alertmanager_nflog_gc_duration_seconds_count has been saved to ./data/alertmanager_nflog_gc_duration_seconds_count.json.gz.
# Data for alertmanager_nflog_gc_duration_seconds_sum has been saved to ./data/alertmanager_nflog_gc_duration_seconds_sum.json.gz.
# Data for alertmanager_nflog_gossip_messages_propagated_total has been saved to ./data/alertmanager_nflog_gossip_messages_propagated_total.json.gz.
# Data for alertmanager_nflog_maintenance_errors_total has been saved to ./data/alertmanager_nflog_maintenance_errors_total.json.gz.
# Data for alertmanager_nflog_maintenance_total has been saved to ./data/alertmanager_nflog_maintenance_total.json.gz.
# Data for alertmanager_nflog_queries_total has been saved to ./data/alertmanager_nflog_queries_total.json.gz.
# Data for alertmanager_nflog_query_duration_seconds_bucket has been saved to ./data/alertmanager_nflog_query_duration_seconds_bucket.json.gz.
# Data for alertmanager_nflog_query_duration_seconds_count has been saved to ./data/alertmanager_nflog_query_duration_seconds_count.json.gz.
# Data for alertmanager_nflog_query_duration_seconds_sum has been saved to ./data/alertmanager_nflog_query_duration_seconds_sum.json.gz.
# Data for alertmanager_nflog_query_errors_total has been saved to ./data/alertmanager_nflog_query_errors_total.json.gz.
# Data for alertmanager_nflog_snapshot_duration_seconds_count has been saved to ./data/alertmanager_nflog_snapshot_duration_seconds_count.json.gz.
# Data for alertmanager_nflog_snapshot_duration_seconds_sum has been saved to ./data/alertmanager_nflog_snapshot_duration_seconds_sum.json.gz.
# Data for alertmanager_nflog_snapshot_size_bytes has been saved to ./data/alertmanager_nflog_snapshot_size_bytes.json.gz.
# Data for alertmanager_notification_latency_seconds_bucket has been saved to ./data/alertmanager_notification_latency_seconds_bucket.json.gz.
# Data for alertmanager_notification_latency_seconds_count has been saved to ./data/alertmanager_notification_latency_seconds_count.json.gz.
# Data for alertmanager_notification_latency_seconds_sum has been saved to ./data/alertmanager_notification_latency_seconds_sum.json.gz.
# Data for alertmanager_notification_requests_failed_total has been saved to ./data/alertmanager_notification_requests_failed_total.json.gz.
# Data for alertmanager_notification_requests_total has been saved to ./data/alertmanager_notification_requests_total.json.gz.
# Data for alertmanager_notifications_failed_total has been saved to ./data/alertmanager_notifications_failed_total.json.gz.
# Data for alertmanager_notifications_total has been saved to ./data/alertmanager_notifications_total.json.gz.
# Data for alertmanager_receivers has been saved to ./data/alertmanager_receivers.json.gz.
# Data for alertmanager_silences has been saved to ./data/alertmanager_silences.json.gz.
# Data for alertmanager_silences_gc_duration_seconds_count has been saved to ./data/alertmanager_silences_gc_duration_seconds_count.json.gz.
# Data for alertmanager_silences_gc_duration_seconds_sum has been saved to ./data/alertmanager_silences_gc_duration_seconds_sum.json.gz.
# Data for alertmanager_silences_gossip_messages_propagated_total has been saved to ./data/alertmanager_silences_gossip_messages_propagated_total.json.gz.
# Data for alertmanager_silences_maintenance_errors_total has been saved to ./data/alertmanager_silences_maintenance_errors_total.json.gz.
# Data for alertmanager_silences_maintenance_total has been saved to ./data/alertmanager_silences_maintenance_total.json.gz.
# Data for alertmanager_silences_queries_total has been saved to ./data/alertmanager_silences_queries_total.json.gz.
# Data for alertmanager_silences_query_duration_seconds_bucket has been saved to ./data/alertmanager_silences_query_duration_seconds_bucket.json.gz.
# Data for alertmanager_silences_query_duration_seconds_count has been saved to ./data/alertmanager_silences_query_duration_seconds_count.json.gz.
# Data for alertmanager_silences_query_duration_seconds_sum has been saved to ./data/alertmanager_silences_query_duration_seconds_sum.json.gz.
# Data for alertmanager_silences_query_errors_total has been saved to ./data/alertmanager_silences_query_errors_total.json.gz.
# Data for alertmanager_silences_snapshot_duration_seconds_count has been saved to ./data/alertmanager_silences_snapshot_duration_seconds_count.json.gz.
# Data for alertmanager_silences_snapshot_duration_seconds_sum has been saved to ./data/alertmanager_silences_snapshot_duration_seconds_sum.json.gz.
# Data for alertmanager_silences_snapshot_size_bytes has been saved to ./data/alertmanager_silences_snapshot_size_bytes.json.gz.
# Data for apiextensions_apiserver_validation_ratcheting_seconds_bucket has been saved to ./data/apiextensions_apiserver_validation_ratcheting_seconds_bucket.json.gz.
# Data for apiextensions_apiserver_validation_ratcheting_seconds_count has been saved to ./data/apiextensions_apiserver_validation_ratcheting_seconds_count.json.gz.
# Data for apiextensions_apiserver_validation_ratcheting_seconds_sum has been saved to ./data/apiextensions_apiserver_validation_ratcheting_seconds_sum.json.gz.
# Data for apiextensions_openapi_v2_regeneration_count has been saved to ./data/apiextensions_openapi_v2_regeneration_count.json.gz.
# Data for apiextensions_openapi_v3_regeneration_count has been saved to ./data/apiextensions_openapi_v3_regeneration_count.json.gz.
# Data for apiserver_admission_controller_admission_duration_seconds_bucket has been saved to ./data/apiserver_admission_controller_admission_duration_seconds_bucket.json.gz.
# Data for apiserver_admission_controller_admission_duration_seconds_count has been saved to ./data/apiserver_admission_controller_admission_duration_seconds_count.json.gz.
# Data for apiserver_admission_controller_admission_duration_seconds_sum has been saved to ./data/apiserver_admission_controller_admission_duration_seconds_sum.json.gz.
# Data for apiserver_admission_step_admission_duration_seconds_bucket has been saved to ./data/apiserver_admission_step_admission_duration_seconds_bucket.json.gz.
# Data for apiserver_admission_step_admission_duration_seconds_count has been saved to ./data/apiserver_admission_step_admission_duration_seconds_count.json.gz.
# Data for apiserver_admission_step_admission_duration_seconds_sum has been saved to ./data/apiserver_admission_step_admission_duration_seconds_sum.json.gz.
# Data for apiserver_admission_step_admission_duration_seconds_summary has been saved to ./data/apiserver_admission_step_admission_duration_seconds_summary.json.gz.
# Data for apiserver_admission_step_admission_duration_seconds_summary_count has been saved to ./data/apiserver_admission_step_admission_duration_seconds_summary_count.json.gz.
# Data for apiserver_admission_step_admission_duration_seconds_summary_sum has been saved to ./data/apiserver_admission_step_admission_duration_seconds_summary_sum.json.gz.
# Data for apiserver_admission_webhook_admission_duration_seconds_bucket has been saved to ./data/apiserver_admission_webhook_admission_duration_seconds_bucket.json.gz.
# Data for apiserver_admission_webhook_admission_duration_seconds_count has been saved to ./data/apiserver_admission_webhook_admission_duration_seconds_count.json.gz.
# Data for apiserver_admission_webhook_admission_duration_seconds_sum has been saved to ./data/apiserver_admission_webhook_admission_duration_seconds_sum.json.gz.
# Data for apiserver_admission_webhook_fail_open_count has been saved to ./data/apiserver_admission_webhook_fail_open_count.json.gz.
# Data for apiserver_admission_webhook_request_total has been saved to ./data/apiserver_admission_webhook_request_total.json.gz.
# Data for apiserver_audit_event_total has been saved to ./data/apiserver_audit_event_total.json.gz.
# Data for apiserver_audit_requests_rejected_total has been saved to ./data/apiserver_audit_requests_rejected_total.json.gz.
# Data for apiserver_cache_list_fetched_objects_total has been saved to ./data/apiserver_cache_list_fetched_objects_total.json.gz.
# Data for apiserver_cache_list_returned_objects_total has been saved to ./data/apiserver_cache_list_returned_objects_total.json.gz.
# Data for apiserver_cache_list_total has been saved to ./data/apiserver_cache_list_total.json.gz.
# Data for apiserver_cel_compilation_duration_seconds_bucket has been saved to ./data/apiserver_cel_compilation_duration_seconds_bucket.json.gz.
# Data for apiserver_cel_compilation_duration_seconds_count has been saved to ./data/apiserver_cel_compilation_duration_seconds_count.json.gz.
# Data for apiserver_cel_compilation_duration_seconds_sum has been saved to ./data/apiserver_cel_compilation_duration_seconds_sum.json.gz.
# Data for apiserver_cel_evaluation_duration_seconds_bucket has been saved to ./data/apiserver_cel_evaluation_duration_seconds_bucket.json.gz.
# Data for apiserver_cel_evaluation_duration_seconds_count has been saved to ./data/apiserver_cel_evaluation_duration_seconds_count.json.gz.
# Data for apiserver_cel_evaluation_duration_seconds_sum has been saved to ./data/apiserver_cel_evaluation_duration_seconds_sum.json.gz.
# Data for apiserver_client_certificate_expiration_seconds_bucket has been saved to ./data/apiserver_client_certificate_expiration_seconds_bucket.json.gz.
# Data for apiserver_client_certificate_expiration_seconds_count has been saved to ./data/apiserver_client_certificate_expiration_seconds_count.json.gz.
# Data for apiserver_client_certificate_expiration_seconds_sum has been saved to ./data/apiserver_client_certificate_expiration_seconds_sum.json.gz.
# Data for apiserver_clusterip_repair_reconcile_errors_total has been saved to ./data/apiserver_clusterip_repair_reconcile_errors_total.json.gz.
# Data for apiserver_current_inflight_requests has been saved to ./data/apiserver_current_inflight_requests.json.gz.
# Data for apiserver_current_inqueue_requests has been saved to ./data/apiserver_current_inqueue_requests.json.gz.
# Data for apiserver_delegated_authn_request_duration_seconds_bucket has been saved to ./data/apiserver_delegated_authn_request_duration_seconds_bucket.json.gz.
# Data for apiserver_delegated_authn_request_duration_seconds_count has been saved to ./data/apiserver_delegated_authn_request_duration_seconds_count.json.gz.
# Data for apiserver_delegated_authn_request_duration_seconds_sum has been saved to ./data/apiserver_delegated_authn_request_duration_seconds_sum.json.gz.
# Data for apiserver_delegated_authn_request_total has been saved to ./data/apiserver_delegated_authn_request_total.json.gz.
# Data for apiserver_delegated_authz_request_duration_seconds_bucket has been saved to ./data/apiserver_delegated_authz_request_duration_seconds_bucket.json.gz.
# Data for apiserver_delegated_authz_request_duration_seconds_count has been saved to ./data/apiserver_delegated_authz_request_duration_seconds_count.json.gz.
# Data for apiserver_delegated_authz_request_duration_seconds_sum has been saved to ./data/apiserver_delegated_authz_request_duration_seconds_sum.json.gz.
# Data for apiserver_delegated_authz_request_total has been saved to ./data/apiserver_delegated_authz_request_total.json.gz.
# Data for apiserver_envelope_encryption_dek_cache_fill_percent has been saved to ./data/apiserver_envelope_encryption_dek_cache_fill_percent.json.gz.
# Data for apiserver_flowcontrol_current_executing_requests has been saved to ./data/apiserver_flowcontrol_current_executing_requests.json.gz.
# Data for apiserver_flowcontrol_current_executing_seats has been saved to ./data/apiserver_flowcontrol_current_executing_seats.json.gz.
# Data for apiserver_flowcontrol_current_inqueue_requests has been saved to ./data/apiserver_flowcontrol_current_inqueue_requests.json.gz.
# Data for apiserver_flowcontrol_current_inqueue_seats has been saved to ./data/apiserver_flowcontrol_current_inqueue_seats.json.gz.
# Data for apiserver_flowcontrol_current_limit_seats has been saved to ./data/apiserver_flowcontrol_current_limit_seats.json.gz.
# Data for apiserver_flowcontrol_current_r has been saved to ./data/apiserver_flowcontrol_current_r.json.gz.
# Data for apiserver_flowcontrol_demand_seats_average has been saved to ./data/apiserver_flowcontrol_demand_seats_average.json.gz.
# Data for apiserver_flowcontrol_demand_seats_bucket has been saved to ./data/apiserver_flowcontrol_demand_seats_bucket.json.gz.
# Data for apiserver_flowcontrol_demand_seats_count has been saved to ./data/apiserver_flowcontrol_demand_seats_count.json.gz.
# Data for apiserver_flowcontrol_demand_seats_high_watermark has been saved to ./data/apiserver_flowcontrol_demand_seats_high_watermark.json.gz.
# Data for apiserver_flowcontrol_demand_seats_smoothed has been saved to ./data/apiserver_flowcontrol_demand_seats_smoothed.json.gz.
# Data for apiserver_flowcontrol_demand_seats_stdev has been saved to ./data/apiserver_flowcontrol_demand_seats_stdev.json.gz.
# Data for apiserver_flowcontrol_demand_seats_sum has been saved to ./data/apiserver_flowcontrol_demand_seats_sum.json.gz.
# Data for apiserver_flowcontrol_dispatch_r has been saved to ./data/apiserver_flowcontrol_dispatch_r.json.gz.
# Data for apiserver_flowcontrol_dispatched_requests_total has been saved to ./data/apiserver_flowcontrol_dispatched_requests_total.json.gz.
# Data for apiserver_flowcontrol_latest_s has been saved to ./data/apiserver_flowcontrol_latest_s.json.gz.
# Data for apiserver_flowcontrol_lower_limit_seats has been saved to ./data/apiserver_flowcontrol_lower_limit_seats.json.gz.
# Data for apiserver_flowcontrol_next_discounted_s_bounds has been saved to ./data/apiserver_flowcontrol_next_discounted_s_bounds.json.gz.
# Data for apiserver_flowcontrol_next_s_bounds has been saved to ./data/apiserver_flowcontrol_next_s_bounds.json.gz.
# Data for apiserver_flowcontrol_nominal_limit_seats has been saved to ./data/apiserver_flowcontrol_nominal_limit_seats.json.gz.
# Data for apiserver_flowcontrol_priority_level_request_utilization_bucket has been saved to ./data/apiserver_flowcontrol_priority_level_request_utilization_bucket.json.gz.
# Data for apiserver_flowcontrol_priority_level_request_utilization_count has been saved to ./data/apiserver_flowcontrol_priority_level_request_utilization_count.json.gz.
# Data for apiserver_flowcontrol_priority_level_request_utilization_sum has been saved to ./data/apiserver_flowcontrol_priority_level_request_utilization_sum.json.gz.
# Data for apiserver_flowcontrol_priority_level_seat_utilization_bucket has been saved to ./data/apiserver_flowcontrol_priority_level_seat_utilization_bucket.json.gz.
# Data for apiserver_flowcontrol_priority_level_seat_utilization_count has been saved to ./data/apiserver_flowcontrol_priority_level_seat_utilization_count.json.gz.
# Data for apiserver_flowcontrol_priority_level_seat_utilization_sum has been saved to ./data/apiserver_flowcontrol_priority_level_seat_utilization_sum.json.gz.
# Data for apiserver_flowcontrol_read_vs_write_current_requests_bucket has been saved to ./data/apiserver_flowcontrol_read_vs_write_current_requests_bucket.json.gz.
# Data for apiserver_flowcontrol_read_vs_write_current_requests_count has been saved to ./data/apiserver_flowcontrol_read_vs_write_current_requests_count.json.gz.
# Data for apiserver_flowcontrol_read_vs_write_current_requests_sum has been saved to ./data/apiserver_flowcontrol_read_vs_write_current_requests_sum.json.gz.
# Data for apiserver_flowcontrol_request_concurrency_in_use has been saved to ./data/apiserver_flowcontrol_request_concurrency_in_use.json.gz.
# Data for apiserver_flowcontrol_request_concurrency_limit has been saved to ./data/apiserver_flowcontrol_request_concurrency_limit.json.gz.
# Data for apiserver_flowcontrol_request_execution_seconds_bucket has been saved to ./data/apiserver_flowcontrol_request_execution_seconds_bucket.json.gz.
# Data for apiserver_flowcontrol_request_execution_seconds_count has been saved to ./data/apiserver_flowcontrol_request_execution_seconds_count.json.gz.
# Data for apiserver_flowcontrol_request_execution_seconds_sum has been saved to ./data/apiserver_flowcontrol_request_execution_seconds_sum.json.gz.
# Data for apiserver_flowcontrol_request_queue_length_after_enqueue_bucket has been saved to ./data/apiserver_flowcontrol_request_queue_length_after_enqueue_bucket.json.gz.
# Data for apiserver_flowcontrol_request_queue_length_after_enqueue_count has been saved to ./data/apiserver_flowcontrol_request_queue_length_after_enqueue_count.json.gz.
# Data for apiserver_flowcontrol_request_queue_length_after_enqueue_sum has been saved to ./data/apiserver_flowcontrol_request_queue_length_after_enqueue_sum.json.gz.
# Data for apiserver_flowcontrol_request_wait_duration_seconds_bucket has been saved to ./data/apiserver_flowcontrol_request_wait_duration_seconds_bucket.json.gz.
# Data for apiserver_flowcontrol_request_wait_duration_seconds_count has been saved to ./data/apiserver_flowcontrol_request_wait_duration_seconds_count.json.gz.
# Data for apiserver_flowcontrol_request_wait_duration_seconds_sum has been saved to ./data/apiserver_flowcontrol_request_wait_duration_seconds_sum.json.gz.
# Data for apiserver_flowcontrol_seat_fair_frac has been saved to ./data/apiserver_flowcontrol_seat_fair_frac.json.gz.
# Data for apiserver_flowcontrol_target_seats has been saved to ./data/apiserver_flowcontrol_target_seats.json.gz.
# Data for apiserver_flowcontrol_upper_limit_seats has been saved to ./data/apiserver_flowcontrol_upper_limit_seats.json.gz.
# Data for apiserver_flowcontrol_watch_count_samples_bucket has been saved to ./data/apiserver_flowcontrol_watch_count_samples_bucket.json.gz.
# Data for apiserver_flowcontrol_watch_count_samples_count has been saved to ./data/apiserver_flowcontrol_watch_count_samples_count.json.gz.
# Data for apiserver_flowcontrol_watch_count_samples_sum has been saved to ./data/apiserver_flowcontrol_watch_count_samples_sum.json.gz.
# Data for apiserver_flowcontrol_work_estimated_seats_bucket has been saved to ./data/apiserver_flowcontrol_work_estimated_seats_bucket.json.gz.
# Data for apiserver_flowcontrol_work_estimated_seats_count has been saved to ./data/apiserver_flowcontrol_work_estimated_seats_count.json.gz.
# Data for apiserver_flowcontrol_work_estimated_seats_sum has been saved to ./data/apiserver_flowcontrol_work_estimated_seats_sum.json.gz.
# Data for apiserver_init_events_total has been saved to ./data/apiserver_init_events_total.json.gz.
# Data for apiserver_kube_aggregator_x509_insecure_sha1_total has been saved to ./data/apiserver_kube_aggregator_x509_insecure_sha1_total.json.gz.
# Data for apiserver_kube_aggregator_x509_missing_san_total has been saved to ./data/apiserver_kube_aggregator_x509_missing_san_total.json.gz.
# Data for apiserver_longrunning_requests has been saved to ./data/apiserver_longrunning_requests.json.gz.
# Data for apiserver_nodeport_repair_reconcile_errors_total has been saved to ./data/apiserver_nodeport_repair_reconcile_errors_total.json.gz.
# Data for apiserver_request:availability30d has been saved to ./data/apiserver_request:availability30d.json.gz.
# Data for apiserver_request:burnrate1d has been saved to ./data/apiserver_request:burnrate1d.json.gz.
# Data for apiserver_request:burnrate1h has been saved to ./data/apiserver_request:burnrate1h.json.gz.
# Data for apiserver_request:burnrate2h has been saved to ./data/apiserver_request:burnrate2h.json.gz.
# Data for apiserver_request:burnrate30m has been saved to ./data/apiserver_request:burnrate30m.json.gz.
# Data for apiserver_request:burnrate3d has been saved to ./data/apiserver_request:burnrate3d.json.gz.
# Data for apiserver_request:burnrate5m has been saved to ./data/apiserver_request:burnrate5m.json.gz.
# Data for apiserver_request:burnrate6h has been saved to ./data/apiserver_request:burnrate6h.json.gz.
# Data for apiserver_request_body_size_bytes_bucket has been saved to ./data/apiserver_request_body_size_bytes_bucket.json.gz.
# Data for apiserver_request_body_size_bytes_count has been saved to ./data/apiserver_request_body_size_bytes_count.json.gz.
# Data for apiserver_request_body_size_bytes_sum has been saved to ./data/apiserver_request_body_size_bytes_sum.json.gz.
# Data for apiserver_request_duration_seconds_bucket has been saved to ./data/apiserver_request_duration_seconds_bucket.json.gz.
# Data for apiserver_request_duration_seconds_count has been saved to ./data/apiserver_request_duration_seconds_count.json.gz.
# Data for apiserver_request_duration_seconds_sum has been saved to ./data/apiserver_request_duration_seconds_sum.json.gz.
# Data for apiserver_request_filter_duration_seconds_bucket has been saved to ./data/apiserver_request_filter_duration_seconds_bucket.json.gz.
# Data for apiserver_request_filter_duration_seconds_count has been saved to ./data/apiserver_request_filter_duration_seconds_count.json.gz.
# Data for apiserver_request_filter_duration_seconds_sum has been saved to ./data/apiserver_request_filter_duration_seconds_sum.json.gz.
# Data for apiserver_request_post_timeout_total has been saved to ./data/apiserver_request_post_timeout_total.json.gz.
# Data for apiserver_request_sli_duration_seconds_bucket has been saved to ./data/apiserver_request_sli_duration_seconds_bucket.json.gz.
# Data for apiserver_request_sli_duration_seconds_count has been saved to ./data/apiserver_request_sli_duration_seconds_count.json.gz.
# Data for apiserver_request_sli_duration_seconds_sum has been saved to ./data/apiserver_request_sli_duration_seconds_sum.json.gz.
# Data for apiserver_request_terminations_total has been saved to ./data/apiserver_request_terminations_total.json.gz.
# Data for apiserver_request_timestamp_comparison_time_bucket has been saved to ./data/apiserver_request_timestamp_comparison_time_bucket.json.gz.
# Data for apiserver_request_timestamp_comparison_time_count has been saved to ./data/apiserver_request_timestamp_comparison_time_count.json.gz.
# Data for apiserver_request_timestamp_comparison_time_sum has been saved to ./data/apiserver_request_timestamp_comparison_time_sum.json.gz.
# Data for apiserver_request_total has been saved to ./data/apiserver_request_total.json.gz.
# Data for apiserver_response_sizes_bucket has been saved to ./data/apiserver_response_sizes_bucket.json.gz.
# Data for apiserver_response_sizes_count has been saved to ./data/apiserver_response_sizes_count.json.gz.
# Data for apiserver_response_sizes_sum has been saved to ./data/apiserver_response_sizes_sum.json.gz.
# Data for apiserver_selfrequest_total has been saved to ./data/apiserver_selfrequest_total.json.gz.
# Data for apiserver_storage_data_key_generation_duration_seconds_bucket has been saved to ./data/apiserver_storage_data_key_generation_duration_seconds_bucket.json.gz.
# Data for apiserver_storage_data_key_generation_duration_seconds_count has been saved to ./data/apiserver_storage_data_key_generation_duration_seconds_count.json.gz.
# Data for apiserver_storage_data_key_generation_duration_seconds_sum has been saved to ./data/apiserver_storage_data_key_generation_duration_seconds_sum.json.gz.
# Data for apiserver_storage_data_key_generation_failures_total has been saved to ./data/apiserver_storage_data_key_generation_failures_total.json.gz.
# Data for apiserver_storage_envelope_transformation_cache_misses_total has been saved to ./data/apiserver_storage_envelope_transformation_cache_misses_total.json.gz.
# Data for apiserver_storage_list_evaluated_objects_total has been saved to ./data/apiserver_storage_list_evaluated_objects_total.json.gz.
# Data for apiserver_storage_list_fetched_objects_total has been saved to ./data/apiserver_storage_list_fetched_objects_total.json.gz.
# Data for apiserver_storage_list_returned_objects_total has been saved to ./data/apiserver_storage_list_returned_objects_total.json.gz.
# Data for apiserver_storage_list_total has been saved to ./data/apiserver_storage_list_total.json.gz.
# Data for apiserver_storage_objects has been saved to ./data/apiserver_storage_objects.json.gz.
# Data for apiserver_storage_size_bytes has been saved to ./data/apiserver_storage_size_bytes.json.gz.
# Data for apiserver_tls_handshake_errors_total has been saved to ./data/apiserver_tls_handshake_errors_total.json.gz.
# Data for apiserver_watch_cache_events_dispatched_total has been saved to ./data/apiserver_watch_cache_events_dispatched_total.json.gz.
# Data for apiserver_watch_cache_events_received_total has been saved to ./data/apiserver_watch_cache_events_received_total.json.gz.
# Data for apiserver_watch_cache_initializations_total has been saved to ./data/apiserver_watch_cache_initializations_total.json.gz.
# Data for apiserver_watch_events_sizes_bucket has been saved to ./data/apiserver_watch_events_sizes_bucket.json.gz.
# Data for apiserver_watch_events_sizes_count has been saved to ./data/apiserver_watch_events_sizes_count.json.gz.
# Data for apiserver_watch_events_sizes_sum has been saved to ./data/apiserver_watch_events_sizes_sum.json.gz.
# Data for apiserver_watch_events_total has been saved to ./data/apiserver_watch_events_total.json.gz.
# Data for apiserver_webhooks_x509_insecure_sha1_total has been saved to ./data/apiserver_webhooks_x509_insecure_sha1_total.json.gz.
# Data for apiserver_webhooks_x509_missing_san_total has been saved to ./data/apiserver_webhooks_x509_missing_san_total.json.gz.
# Data for authenticated_user_requests has been saved to ./data/authenticated_user_requests.json.gz.
# Data for authentication_attempts has been saved to ./data/authentication_attempts.json.gz.
# Data for authentication_duration_seconds_bucket has been saved to ./data/authentication_duration_seconds_bucket.json.gz.
# Data for authentication_duration_seconds_count has been saved to ./data/authentication_duration_seconds_count.json.gz.
# Data for authentication_duration_seconds_sum has been saved to ./data/authentication_duration_seconds_sum.json.gz.
# Data for authentication_token_cache_active_fetch_count has been saved to ./data/authentication_token_cache_active_fetch_count.json.gz.
# Data for authentication_token_cache_fetch_total has been saved to ./data/authentication_token_cache_fetch_total.json.gz.
# Data for authentication_token_cache_request_duration_seconds_bucket has been saved to ./data/authentication_token_cache_request_duration_seconds_bucket.json.gz.
# Data for authentication_token_cache_request_duration_seconds_count has been saved to ./data/authentication_token_cache_request_duration_seconds_count.json.gz.
# Data for authentication_token_cache_request_duration_seconds_sum has been saved to ./data/authentication_token_cache_request_duration_seconds_sum.json.gz.
# Data for authentication_token_cache_request_total has been saved to ./data/authentication_token_cache_request_total.json.gz.
# Data for authorization_attempts_total has been saved to ./data/authorization_attempts_total.json.gz.
# Data for authorization_duration_seconds_bucket has been saved to ./data/authorization_duration_seconds_bucket.json.gz.
# Data for authorization_duration_seconds_count has been saved to ./data/authorization_duration_seconds_count.json.gz.
# Data for authorization_duration_seconds_sum has been saved to ./data/authorization_duration_seconds_sum.json.gz.
# Data for cadvisor_version_info has been saved to ./data/cadvisor_version_info.json.gz.
# Data for cardinality_enforcement_unexpected_categorizations_total has been saved to ./data/cardinality_enforcement_unexpected_categorizations_total.json.gz.
# Data for cluster:namespace:pod_cpu:active:kube_pod_container_resource_requests has been saved to ./data/cluster:namespace:pod_cpu:active:kube_pod_container_resource_requests.json.gz.
# Data for cluster:namespace:pod_memory:active:kube_pod_container_resource_limits has been saved to ./data/cluster:namespace:pod_memory:active:kube_pod_container_resource_limits.json.gz.
# Data for cluster:namespace:pod_memory:active:kube_pod_container_resource_requests has been saved to ./data/cluster:namespace:pod_memory:active:kube_pod_container_resource_requests.json.gz.
# Data for cluster:node_cpu:ratio has been saved to ./data/cluster:node_cpu:ratio.json.gz.
# Data for cluster:node_cpu:ratio_rate5m has been saved to ./data/cluster:node_cpu:ratio_rate5m.json.gz.
# Data for cluster:node_cpu:sum_rate5m has been saved to ./data/cluster:node_cpu:sum_rate5m.json.gz.
# Data for cluster_quantile:apiserver_request_sli_duration_seconds:histogram_quantile has been saved to ./data/cluster_quantile:apiserver_request_sli_duration_seconds:histogram_quantile.json.gz.
# Data for cluster_verb_scope:apiserver_request_sli_duration_seconds_count:increase1h has been saved to ./data/cluster_verb_scope:apiserver_request_sli_duration_seconds_count:increase1h.json.gz.
# Data for cluster_verb_scope:apiserver_request_sli_duration_seconds_count:increase30d has been saved to ./data/cluster_verb_scope:apiserver_request_sli_duration_seconds_count:increase30d.json.gz.
# Data for cluster_verb_scope_le:apiserver_request_sli_duration_seconds_bucket:increase1h has been saved to ./data/cluster_verb_scope_le:apiserver_request_sli_duration_seconds_bucket:increase1h.json.gz.
# Data for cluster_verb_scope_le:apiserver_request_sli_duration_seconds_bucket:increase30d has been saved to ./data/cluster_verb_scope_le:apiserver_request_sli_duration_seconds_bucket:increase30d.json.gz.
# Data for code:apiserver_request_total:increase30d has been saved to ./data/code:apiserver_request_total:increase30d.json.gz.
# Data for code_resource:apiserver_request_total:rate5m has been saved to ./data/code_resource:apiserver_request_total:rate5m.json.gz.
# Data for code_verb:apiserver_request_total:increase1h has been saved to ./data/code_verb:apiserver_request_total:increase1h.json.gz.
# Data for code_verb:apiserver_request_total:increase30d has been saved to ./data/code_verb:apiserver_request_total:increase30d.json.gz.
# Data for container_blkio_device_usage_total has been saved to ./data/container_blkio_device_usage_total.json.gz.
# Data for container_cpu_usage_seconds_total has been saved to ./data/container_cpu_usage_seconds_total.json.gz.
# Data for container_fs_reads_bytes_total has been saved to ./data/container_fs_reads_bytes_total.json.gz.
# Data for container_fs_reads_total has been saved to ./data/container_fs_reads_total.json.gz.
# Data for container_fs_writes_bytes_total has been saved to ./data/container_fs_writes_bytes_total.json.gz.
# Data for container_fs_writes_total has been saved to ./data/container_fs_writes_total.json.gz.
# Data for container_last_seen has been saved to ./data/container_last_seen.json.gz.
# Data for container_memory_cache has been saved to ./data/container_memory_cache.json.gz.
# Data for container_memory_failcnt has been saved to ./data/container_memory_failcnt.json.gz.
# Data for container_memory_failures_total has been saved to ./data/container_memory_failures_total.json.gz.
# Data for container_memory_kernel_usage has been saved to ./data/container_memory_kernel_usage.json.gz.
# Data for container_memory_max_usage_bytes has been saved to ./data/container_memory_max_usage_bytes.json.gz.
# Data for container_memory_rss has been saved to ./data/container_memory_rss.json.gz.
# Data for container_memory_usage_bytes has been saved to ./data/container_memory_usage_bytes.json.gz.
# Data for container_memory_working_set_bytes has been saved to ./data/container_memory_working_set_bytes.json.gz.
# Data for container_network_receive_bytes_total has been saved to ./data/container_network_receive_bytes_total.json.gz.
# Data for container_network_receive_errors_total has been saved to ./data/container_network_receive_errors_total.json.gz.
# Data for container_network_receive_packets_dropped_total has been saved to ./data/container_network_receive_packets_dropped_total.json.gz.
# Data for container_network_receive_packets_total has been saved to ./data/container_network_receive_packets_total.json.gz.
# Data for container_network_transmit_bytes_total has been saved to ./data/container_network_transmit_bytes_total.json.gz.
# Data for container_network_transmit_errors_total has been saved to ./data/container_network_transmit_errors_total.json.gz.
# Data for container_network_transmit_packets_dropped_total has been saved to ./data/container_network_transmit_packets_dropped_total.json.gz.
# Data for container_network_transmit_packets_total has been saved to ./data/container_network_transmit_packets_total.json.gz.
# Data for container_oom_events_total has been saved to ./data/container_oom_events_total.json.gz.
# Data for container_processes has been saved to ./data/container_processes.json.gz.
# Data for container_scrape_error has been saved to ./data/container_scrape_error.json.gz.
# Data for container_sockets has been saved to ./data/container_sockets.json.gz.
# Data for container_start_time_seconds has been saved to ./data/container_start_time_seconds.json.gz.
# Data for container_threads has been saved to ./data/container_threads.json.gz.
# Data for container_ulimits_soft has been saved to ./data/container_ulimits_soft.json.gz.
# Data for coredns_build_info has been saved to ./data/coredns_build_info.json.gz.
# Data for coredns_cache_entries has been saved to ./data/coredns_cache_entries.json.gz.
# Data for coredns_cache_hits_total has been saved to ./data/coredns_cache_hits_total.json.gz.
# Data for coredns_cache_misses_total has been saved to ./data/coredns_cache_misses_total.json.gz.
# Data for coredns_cache_requests_total has been saved to ./data/coredns_cache_requests_total.json.gz.
# Data for coredns_dns_request_duration_seconds_bucket has been saved to ./data/coredns_dns_request_duration_seconds_bucket.json.gz.
# Data for coredns_dns_request_duration_seconds_count has been saved to ./data/coredns_dns_request_duration_seconds_count.json.gz.
# Data for coredns_dns_request_duration_seconds_sum has been saved to ./data/coredns_dns_request_duration_seconds_sum.json.gz.
# Data for coredns_dns_request_size_bytes_bucket has been saved to ./data/coredns_dns_request_size_bytes_bucket.json.gz.
# Data for coredns_dns_request_size_bytes_count has been saved to ./data/coredns_dns_request_size_bytes_count.json.gz.
# Data for coredns_dns_request_size_bytes_sum has been saved to ./data/coredns_dns_request_size_bytes_sum.json.gz.
# Data for coredns_dns_requests_total has been saved to ./data/coredns_dns_requests_total.json.gz.
# Data for coredns_dns_response_size_bytes_bucket has been saved to ./data/coredns_dns_response_size_bytes_bucket.json.gz.
# Data for coredns_dns_response_size_bytes_count has been saved to ./data/coredns_dns_response_size_bytes_count.json.gz.
# Data for coredns_dns_response_size_bytes_sum has been saved to ./data/coredns_dns_response_size_bytes_sum.json.gz.
# Data for coredns_dns_responses_total has been saved to ./data/coredns_dns_responses_total.json.gz.
# Data for coredns_forward_healthcheck_broken_total has been saved to ./data/coredns_forward_healthcheck_broken_total.json.gz.
# Data for coredns_forward_max_concurrent_rejects_total has been saved to ./data/coredns_forward_max_concurrent_rejects_total.json.gz.
# Data for coredns_health_request_duration_seconds_bucket has been saved to ./data/coredns_health_request_duration_seconds_bucket.json.gz.
# Data for coredns_health_request_duration_seconds_count has been saved to ./data/coredns_health_request_duration_seconds_count.json.gz.
# Data for coredns_health_request_duration_seconds_sum has been saved to ./data/coredns_health_request_duration_seconds_sum.json.gz.
# Data for coredns_health_request_failures_total has been saved to ./data/coredns_health_request_failures_total.json.gz.
# Data for coredns_hosts_reload_timestamp_seconds has been saved to ./data/coredns_hosts_reload_timestamp_seconds.json.gz.
# Data for coredns_kubernetes_dns_programming_duration_seconds_bucket has been saved to ./data/coredns_kubernetes_dns_programming_duration_seconds_bucket.json.gz.
# Data for coredns_kubernetes_dns_programming_duration_seconds_count has been saved to ./data/coredns_kubernetes_dns_programming_duration_seconds_count.json.gz.
# Data for coredns_kubernetes_dns_programming_duration_seconds_sum has been saved to ./data/coredns_kubernetes_dns_programming_duration_seconds_sum.json.gz.
# Data for coredns_kubernetes_rest_client_rate_limiter_duration_seconds_bucket has been saved to ./data/coredns_kubernetes_rest_client_rate_limiter_duration_seconds_bucket.json.gz.
# Data for coredns_kubernetes_rest_client_rate_limiter_duration_seconds_count has been saved to ./data/coredns_kubernetes_rest_client_rate_limiter_duration_seconds_count.json.gz.
# Data for coredns_kubernetes_rest_client_rate_limiter_duration_seconds_sum has been saved to ./data/coredns_kubernetes_rest_client_rate_limiter_duration_seconds_sum.json.gz.
# Data for coredns_kubernetes_rest_client_request_duration_seconds_bucket has been saved to ./data/coredns_kubernetes_rest_client_request_duration_seconds_bucket.json.gz.
# Data for coredns_kubernetes_rest_client_request_duration_seconds_count has been saved to ./data/coredns_kubernetes_rest_client_request_duration_seconds_count.json.gz.
# Data for coredns_kubernetes_rest_client_request_duration_seconds_sum has been saved to ./data/coredns_kubernetes_rest_client_request_duration_seconds_sum.json.gz.
# Data for coredns_kubernetes_rest_client_requests_total has been saved to ./data/coredns_kubernetes_rest_client_requests_total.json.gz.
# Data for coredns_local_localhost_requests_total has been saved to ./data/coredns_local_localhost_requests_total.json.gz.
# Data for coredns_panics_total has been saved to ./data/coredns_panics_total.json.gz.
# Data for coredns_plugin_enabled has been saved to ./data/coredns_plugin_enabled.json.gz.
# Data for coredns_proxy_conn_cache_hits_total has been saved to ./data/coredns_proxy_conn_cache_hits_total.json.gz.
# Data for coredns_proxy_conn_cache_misses_total has been saved to ./data/coredns_proxy_conn_cache_misses_total.json.gz.
# Data for coredns_proxy_request_duration_seconds_bucket has been saved to ./data/coredns_proxy_request_duration_seconds_bucket.json.gz.
# Data for coredns_proxy_request_duration_seconds_count has been saved to ./data/coredns_proxy_request_duration_seconds_count.json.gz.
# Data for coredns_proxy_request_duration_seconds_sum has been saved to ./data/coredns_proxy_request_duration_seconds_sum.json.gz.
# Data for coredns_reload_failed_total has been saved to ./data/coredns_reload_failed_total.json.gz.
# Data for count:up0 has been saved to ./data/count:up0.json.gz.
# Data for count:up1 has been saved to ./data/count:up1.json.gz.
# Data for disabled_metrics_total has been saved to ./data/disabled_metrics_total.json.gz.
# Data for etcd_bookmark_counts has been saved to ./data/etcd_bookmark_counts.json.gz.
# Data for etcd_lease_object_counts_bucket has been saved to ./data/etcd_lease_object_counts_bucket.json.gz.
# Data for etcd_lease_object_counts_count has been saved to ./data/etcd_lease_object_counts_count.json.gz.
# Data for etcd_lease_object_counts_sum has been saved to ./data/etcd_lease_object_counts_sum.json.gz.
# Data for etcd_request_duration_seconds_bucket has been saved to ./data/etcd_request_duration_seconds_bucket.json.gz.
# Data for etcd_request_duration_seconds_count has been saved to ./data/etcd_request_duration_seconds_count.json.gz.
# Data for etcd_request_duration_seconds_sum has been saved to ./data/etcd_request_duration_seconds_sum.json.gz.
# Data for etcd_request_errors_total has been saved to ./data/etcd_request_errors_total.json.gz.
# Data for etcd_requests_total has been saved to ./data/etcd_requests_total.json.gz.
# Data for field_validation_request_duration_seconds_bucket has been saved to ./data/field_validation_request_duration_seconds_bucket.json.gz.
# Data for field_validation_request_duration_seconds_count has been saved to ./data/field_validation_request_duration_seconds_count.json.gz.
# Data for field_validation_request_duration_seconds_sum has been saved to ./data/field_validation_request_duration_seconds_sum.json.gz.
# Data for force_cleaned_failed_volume_operation_errors_total has been saved to ./data/force_cleaned_failed_volume_operation_errors_total.json.gz.
# Data for force_cleaned_failed_volume_operations_total has been saved to ./data/force_cleaned_failed_volume_operations_total.json.gz.
# Data for get_token_count has been saved to ./data/get_token_count.json.gz.
# Data for get_token_fail_count has been saved to ./data/get_token_fail_count.json.gz.
# Data for go_cgo_go_to_c_calls_calls_total has been saved to ./data/go_cgo_go_to_c_calls_calls_total.json.gz.
# Data for go_cpu_classes_gc_mark_assist_cpu_seconds_total has been saved to ./data/go_cpu_classes_gc_mark_assist_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_gc_mark_dedicated_cpu_seconds_total has been saved to ./data/go_cpu_classes_gc_mark_dedicated_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_gc_mark_idle_cpu_seconds_total has been saved to ./data/go_cpu_classes_gc_mark_idle_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_gc_pause_cpu_seconds_total has been saved to ./data/go_cpu_classes_gc_pause_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_gc_total_cpu_seconds_total has been saved to ./data/go_cpu_classes_gc_total_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_idle_cpu_seconds_total has been saved to ./data/go_cpu_classes_idle_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_scavenge_assist_cpu_seconds_total has been saved to ./data/go_cpu_classes_scavenge_assist_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_scavenge_background_cpu_seconds_total has been saved to ./data/go_cpu_classes_scavenge_background_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_scavenge_total_cpu_seconds_total has been saved to ./data/go_cpu_classes_scavenge_total_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_total_cpu_seconds_total has been saved to ./data/go_cpu_classes_total_cpu_seconds_total.json.gz.
# Data for go_cpu_classes_user_cpu_seconds_total has been saved to ./data/go_cpu_classes_user_cpu_seconds_total.json.gz.
# Data for go_gc_cycles_automatic_gc_cycles_total has been saved to ./data/go_gc_cycles_automatic_gc_cycles_total.json.gz.
# Data for go_gc_cycles_forced_gc_cycles_total has been saved to ./data/go_gc_cycles_forced_gc_cycles_total.json.gz.
# Data for go_gc_cycles_total_gc_cycles_total has been saved to ./data/go_gc_cycles_total_gc_cycles_total.json.gz.
# Data for go_gc_duration_seconds has been saved to ./data/go_gc_duration_seconds.json.gz.
# Data for go_gc_duration_seconds_count has been saved to ./data/go_gc_duration_seconds_count.json.gz.
# Data for go_gc_duration_seconds_sum has been saved to ./data/go_gc_duration_seconds_sum.json.gz.
# Data for go_gc_gogc_percent has been saved to ./data/go_gc_gogc_percent.json.gz.
# Data for go_gc_gomemlimit_bytes has been saved to ./data/go_gc_gomemlimit_bytes.json.gz.
# Data for go_gc_heap_allocs_by_size_bytes_bucket has been saved to ./data/go_gc_heap_allocs_by_size_bytes_bucket.json.gz.
# Data for go_gc_heap_allocs_by_size_bytes_count has been saved to ./data/go_gc_heap_allocs_by_size_bytes_count.json.gz.
# Data for go_gc_heap_allocs_by_size_bytes_sum has been saved to ./data/go_gc_heap_allocs_by_size_bytes_sum.json.gz.
# Data for go_gc_heap_allocs_bytes_total has been saved to ./data/go_gc_heap_allocs_bytes_total.json.gz.
# Data for go_gc_heap_allocs_objects_total has been saved to ./data/go_gc_heap_allocs_objects_total.json.gz.
# Data for go_gc_heap_frees_by_size_bytes_bucket has been saved to ./data/go_gc_heap_frees_by_size_bytes_bucket.json.gz.
# Data for go_gc_heap_frees_by_size_bytes_count has been saved to ./data/go_gc_heap_frees_by_size_bytes_count.json.gz.
# Data for go_gc_heap_frees_by_size_bytes_sum has been saved to ./data/go_gc_heap_frees_by_size_bytes_sum.json.gz.
# Data for go_gc_heap_frees_bytes_total has been saved to ./data/go_gc_heap_frees_bytes_total.json.gz.
# Data for go_gc_heap_frees_objects_total has been saved to ./data/go_gc_heap_frees_objects_total.json.gz.
# Data for go_gc_heap_goal_bytes has been saved to ./data/go_gc_heap_goal_bytes.json.gz.
# Data for go_gc_heap_live_bytes has been saved to ./data/go_gc_heap_live_bytes.json.gz.
# Data for go_gc_heap_objects_objects has been saved to ./data/go_gc_heap_objects_objects.json.gz.
# Data for go_gc_heap_tiny_allocs_objects_total has been saved to ./data/go_gc_heap_tiny_allocs_objects_total.json.gz.
# Data for go_gc_limiter_last_enabled_gc_cycle has been saved to ./data/go_gc_limiter_last_enabled_gc_cycle.json.gz.
# Data for go_gc_pauses_seconds_bucket has been saved to ./data/go_gc_pauses_seconds_bucket.json.gz.
# Data for go_gc_pauses_seconds_count has been saved to ./data/go_gc_pauses_seconds_count.json.gz.
# Data for go_gc_pauses_seconds_sum has been saved to ./data/go_gc_pauses_seconds_sum.json.gz.
# Data for go_gc_scan_globals_bytes has been saved to ./data/go_gc_scan_globals_bytes.json.gz.
# Data for go_gc_scan_heap_bytes has been saved to ./data/go_gc_scan_heap_bytes.json.gz.
# Data for go_gc_scan_stack_bytes has been saved to ./data/go_gc_scan_stack_bytes.json.gz.
# Data for go_gc_scan_total_bytes has been saved to ./data/go_gc_scan_total_bytes.json.gz.
# Data for go_gc_stack_starting_size_bytes has been saved to ./data/go_gc_stack_starting_size_bytes.json.gz.
# Data for go_godebug_non_default_behavior_execerrdot_events_total has been saved to ./data/go_godebug_non_default_behavior_execerrdot_events_total.json.gz.
# ...
# Data for prometheus_tsdb_exemplar_exemplars_in_storage has been saved to ./data/prometheus_tsdb_exemplar_exemplars_in_storage.json.gz.
# Data for prometheus_tsdb_exemplar_last_exemplars_timestamp_seconds has been saved to ./data/prometheus_tsdb_exemplar_last_exemplars_timestamp_seconds.json.gz.
# Data for prometheus_tsdb_exemplar_max_exemplars has been saved to ./data/prometheus_tsdb_exemplar_max_exemplars.json.gz.
# Data for prometheus_tsdb_exemplar_out_of_order_exemplars_total has been saved to ./data/prometheus_tsdb_exemplar_out_of_order_exemplars_total.json.gz.
# Data for prometheus_tsdb_exemplar_series_with_exemplars_in_storage has been saved to ./data/prometheus_tsdb_exemplar_series_with_exemplars_in_storage.json.gz.
# Data for prometheus_tsdb_head_active_appenders has been saved to ./data/prometheus_tsdb_head_active_appenders.json.gz.
# Data for prometheus_tsdb_head_chunks has been saved to ./data/prometheus_tsdb_head_chunks.json.gz.
# Data for prometheus_tsdb_head_chunks_created_total has been saved to ./data/prometheus_tsdb_head_chunks_created_total.json.gz.
# Data for prometheus_tsdb_head_chunks_removed_total has been saved to ./data/prometheus_tsdb_head_chunks_removed_total.json.gz.
# Data for prometheus_tsdb_head_chunks_storage_size_bytes has been saved to ./data/prometheus_tsdb_head_chunks_storage_size_bytes.json.gz.
# Data for prometheus_tsdb_head_gc_duration_seconds_count has been saved to ./data/prometheus_tsdb_head_gc_duration_seconds_count.json.gz.
# Data for prometheus_tsdb_head_gc_duration_seconds_sum has been saved to ./data/prometheus_tsdb_head_gc_duration_seconds_sum.json.gz.
# Data for prometheus_tsdb_head_max_time has been saved to ./data/prometheus_tsdb_head_max_time.json.gz.
# Data for prometheus_tsdb_head_max_time_seconds has been saved to ./data/prometheus_tsdb_head_max_time_seconds.json.gz.
# Data for prometheus_tsdb_head_min_time has been saved to ./data/prometheus_tsdb_head_min_time.json.gz.
# Data for prometheus_tsdb_head_min_time_seconds has been saved to ./data/prometheus_tsdb_head_min_time_seconds.json.gz.
# Data for prometheus_tsdb_head_out_of_order_samples_appended_total has been saved to ./data/prometheus_tsdb_head_out_of_order_samples_appended_total.json.gz.
# Data for prometheus_tsdb_head_samples_appended_total has been saved to ./data/prometheus_tsdb_head_samples_appended_total.json.gz.
# Data for prometheus_tsdb_head_series has been saved to ./data/prometheus_tsdb_head_series.json.gz.
# Data for prometheus_tsdb_head_series_created_total has been saved to ./data/prometheus_tsdb_head_series_created_total.json.gz.
# Data for prometheus_tsdb_head_series_not_found_total has been saved to ./data/prometheus_tsdb_head_series_not_found_total.json.gz.
# Data for prometheus_tsdb_head_series_removed_total has been saved to ./data/prometheus_tsdb_head_series_removed_total.json.gz.
# Data for prometheus_tsdb_head_truncations_failed_total has been saved to ./data/prometheus_tsdb_head_truncations_failed_total.json.gz.
# Data for prometheus_tsdb_head_truncations_total has been saved to ./data/prometheus_tsdb_head_truncations_total.json.gz.
# Data for prometheus_tsdb_isolation_high_watermark has been saved to ./data/prometheus_tsdb_isolation_high_watermark.json.gz.
# Data for prometheus_tsdb_isolation_low_watermark has been saved to ./data/prometheus_tsdb_isolation_low_watermark.json.gz.
# Data for prometheus_tsdb_lowest_timestamp has been saved to ./data/prometheus_tsdb_lowest_timestamp.json.gz.
# Data for prometheus_tsdb_lowest_timestamp_seconds has been saved to ./data/prometheus_tsdb_lowest_timestamp_seconds.json.gz.
# Data for prometheus_tsdb_mmap_chunk_corruptions_total has been saved to ./data/prometheus_tsdb_mmap_chunk_corruptions_total.json.gz.
# Data for prometheus_tsdb_mmap_chunks_total has been saved to ./data/prometheus_tsdb_mmap_chunks_total.json.gz.
# Data for prometheus_tsdb_out_of_bound_samples_total has been saved to ./data/prometheus_tsdb_out_of_bound_samples_total.json.gz.
# Data for prometheus_tsdb_out_of_order_samples_total has been saved to ./data/prometheus_tsdb_out_of_order_samples_total.json.gz.
# Data for prometheus_tsdb_reloads_failures_total has been saved to ./data/prometheus_tsdb_reloads_failures_total.json.gz.
# Data for prometheus_tsdb_reloads_total has been saved to ./data/prometheus_tsdb_reloads_total.json.gz.
# Data for prometheus_tsdb_retention_limit_bytes has been saved to ./data/prometheus_tsdb_retention_limit_bytes.json.gz.
# Data for prometheus_tsdb_retention_limit_seconds has been saved to ./data/prometheus_tsdb_retention_limit_seconds.json.gz.
# Data for prometheus_tsdb_size_retentions_total has been saved to ./data/prometheus_tsdb_size_retentions_total.json.gz.
# Data for prometheus_tsdb_snapshot_replay_error_total has been saved to ./data/prometheus_tsdb_snapshot_replay_error_total.json.gz.
# Data for prometheus_tsdb_storage_blocks_bytes has been saved to ./data/prometheus_tsdb_storage_blocks_bytes.json.gz.
# Data for prometheus_tsdb_symbol_table_size_bytes has been saved to ./data/prometheus_tsdb_symbol_table_size_bytes.json.gz.
# Data for prometheus_tsdb_time_retentions_total has been saved to ./data/prometheus_tsdb_time_retentions_total.json.gz.
# Data for prometheus_tsdb_tombstone_cleanup_seconds_bucket has been saved to ./data/prometheus_tsdb_tombstone_cleanup_seconds_bucket.json.gz.
# Data for prometheus_tsdb_tombstone_cleanup_seconds_count has been saved to ./data/prometheus_tsdb_tombstone_cleanup_seconds_count.json.gz.
# Data for prometheus_tsdb_tombstone_cleanup_seconds_sum has been saved to ./data/prometheus_tsdb_tombstone_cleanup_seconds_sum.json.gz.
# Data for prometheus_tsdb_too_old_samples_total has been saved to ./data/prometheus_tsdb_too_old_samples_total.json.gz.
# Data for prometheus_tsdb_vertical_compactions_total has been saved to ./data/prometheus_tsdb_vertical_compactions_total.json.gz.
# Data for prometheus_tsdb_wal_completed_pages_total has been saved to ./data/prometheus_tsdb_wal_completed_pages_total.json.gz.
# Data for prometheus_tsdb_wal_corruptions_total has been saved to ./data/prometheus_tsdb_wal_corruptions_total.json.gz.
# Data for prometheus_tsdb_wal_fsync_duration_seconds has been saved to ./data/prometheus_tsdb_wal_fsync_duration_seconds.json.gz.
# Data for prometheus_tsdb_wal_fsync_duration_seconds_count has been saved to ./data/prometheus_tsdb_wal_fsync_duration_seconds_count.json.gz.
# Data for prometheus_tsdb_wal_fsync_duration_seconds_sum has been saved to ./data/prometheus_tsdb_wal_fsync_duration_seconds_sum.json.gz.
# Data for prometheus_tsdb_wal_page_flushes_total has been saved to ./data/prometheus_tsdb_wal_page_flushes_total.json.gz.
# Data for prometheus_tsdb_wal_segment_current has been saved to ./data/prometheus_tsdb_wal_segment_current.json.gz.
# Data for prometheus_tsdb_wal_storage_size_bytes has been saved to ./data/prometheus_tsdb_wal_storage_size_bytes.json.gz.
# Data for prometheus_tsdb_wal_truncate_duration_seconds_count has been saved to ./data/prometheus_tsdb_wal_truncate_duration_seconds_count.json.gz.
# Data for prometheus_tsdb_wal_truncate_duration_seconds_sum has been saved to ./data/prometheus_tsdb_wal_truncate_duration_seconds_sum.json.gz.
# Data for prometheus_tsdb_wal_truncations_failed_total has been saved to ./data/prometheus_tsdb_wal_truncations_failed_total.json.gz.
# Data for prometheus_tsdb_wal_truncations_total has been saved to ./data/prometheus_tsdb_wal_truncations_total.json.gz.
# Data for prometheus_tsdb_wal_writes_failed_total has been saved to ./data/prometheus_tsdb_wal_writes_failed_total.json.gz.
# Data for prometheus_web_federation_errors_total has been saved to ./data/prometheus_web_federation_errors_total.json.gz.
# Data for prometheus_web_federation_warnings_total has been saved to ./data/prometheus_web_federation_warnings_total.json.gz.
# Data for promhttp_metric_handler_errors_total has been saved to ./data/promhttp_metric_handler_errors_total.json.gz.
# Data for promhttp_metric_handler_requests_in_flight has been saved to ./data/promhttp_metric_handler_requests_in_flight.json.gz.
# Data for promhttp_metric_handler_requests_total has been saved to ./data/promhttp_metric_handler_requests_total.json.gz.
# Data for reconstruct_volume_operations_errors_total has been saved to ./data/reconstruct_volume_operations_errors_total.json.gz.
# Data for reconstruct_volume_operations_total has been saved to ./data/reconstruct_volume_operations_total.json.gz.
# Data for registered_metrics_total has been saved to ./data/registered_metrics_total.json.gz.
# Data for reloader_config_apply_operations_failed_total has been saved to ./data/reloader_config_apply_operations_failed_total.json.gz.
# Data for reloader_config_apply_operations_total has been saved to ./data/reloader_config_apply_operations_total.json.gz.
# Data for reloader_info has been saved to ./data/reloader_info.json.gz.
# Data for reloader_last_reload_success_timestamp_seconds has been saved to ./data/reloader_last_reload_success_timestamp_seconds.json.gz.
# Data for reloader_last_reload_successful has been saved to ./data/reloader_last_reload_successful.json.gz.
# Data for reloader_reloads_failed_total has been saved to ./data/reloader_reloads_failed_total.json.gz.
# Data for reloader_reloads_total has been saved to ./data/reloader_reloads_total.json.gz.
# Data for reloader_watch_errors_total has been saved to ./data/reloader_watch_errors_total.json.gz.
# Data for reloader_watch_events_total has been saved to ./data/reloader_watch_events_total.json.gz.
# Data for reloader_watches has been saved to ./data/reloader_watches.json.gz.
# Data for rest_client_exec_plugin_certificate_rotation_age_bucket has been saved to ./data/rest_client_exec_plugin_certificate_rotation_age_bucket.json.gz.
# Data for rest_client_exec_plugin_certificate_rotation_age_count has been saved to ./data/rest_client_exec_plugin_certificate_rotation_age_count.json.gz.
# Data for rest_client_exec_plugin_certificate_rotation_age_sum has been saved to ./data/rest_client_exec_plugin_certificate_rotation_age_sum.json.gz.
# Data for rest_client_exec_plugin_ttl_seconds has been saved to ./data/rest_client_exec_plugin_ttl_seconds.json.gz.
# Data for rest_client_rate_limiter_duration_seconds_bucket has been saved to ./data/rest_client_rate_limiter_duration_seconds_bucket.json.gz.
# Data for rest_client_rate_limiter_duration_seconds_count has been saved to ./data/rest_client_rate_limiter_duration_seconds_count.json.gz.
# Data for rest_client_rate_limiter_duration_seconds_sum has been saved to ./data/rest_client_rate_limiter_duration_seconds_sum.json.gz.
# Data for rest_client_request_duration_seconds_bucket has been saved to ./data/rest_client_request_duration_seconds_bucket.json.gz.
# Data for rest_client_request_duration_seconds_count has been saved to ./data/rest_client_request_duration_seconds_count.json.gz.
# Data for rest_client_request_duration_seconds_sum has been saved to ./data/rest_client_request_duration_seconds_sum.json.gz.
# Data for rest_client_request_retries_total has been saved to ./data/rest_client_request_retries_total.json.gz.
# Data for rest_client_request_size_bytes_bucket has been saved to ./data/rest_client_request_size_bytes_bucket.json.gz.
# Data for rest_client_request_size_bytes_count has been saved to ./data/rest_client_request_size_bytes_count.json.gz.
# Data for rest_client_request_size_bytes_sum has been saved to ./data/rest_client_request_size_bytes_sum.json.gz.
# Data for rest_client_requests_total has been saved to ./data/rest_client_requests_total.json.gz.
# Data for rest_client_response_size_bytes_bucket has been saved to ./data/rest_client_response_size_bytes_bucket.json.gz.
# Data for rest_client_response_size_bytes_count has been saved to ./data/rest_client_response_size_bytes_count.json.gz.
# Data for rest_client_response_size_bytes_sum has been saved to ./data/rest_client_response_size_bytes_sum.json.gz.
# Data for rest_client_transport_cache_entries has been saved to ./data/rest_client_transport_cache_entries.json.gz.
# Data for rest_client_transport_create_calls_total has been saved to ./data/rest_client_transport_create_calls_total.json.gz.
# Data for scrape_duration_seconds has been saved to ./data/scrape_duration_seconds.json.gz.
# Data for scrape_samples_post_metric_relabeling has been saved to ./data/scrape_samples_post_metric_relabeling.json.gz.
# Data for scrape_samples_scraped has been saved to ./data/scrape_samples_scraped.json.gz.
# Data for scrape_series_added has been saved to ./data/scrape_series_added.json.gz.
# Data for serviceaccount_invalid_legacy_auto_token_uses_total has been saved to ./data/serviceaccount_invalid_legacy_auto_token_uses_total.json.gz.
# Data for serviceaccount_legacy_auto_token_uses_total has been saved to ./data/serviceaccount_legacy_auto_token_uses_total.json.gz.
# Data for serviceaccount_legacy_manual_token_uses_total has been saved to ./data/serviceaccount_legacy_manual_token_uses_total.json.gz.
# Data for serviceaccount_legacy_tokens_total has been saved to ./data/serviceaccount_legacy_tokens_total.json.gz.
# Data for serviceaccount_stale_tokens_total has been saved to ./data/serviceaccount_stale_tokens_total.json.gz.
# Data for serviceaccount_valid_tokens_total has been saved to ./data/serviceaccount_valid_tokens_total.json.gz.
# Data for storage_operation_duration_seconds_bucket has been saved to ./data/storage_operation_duration_seconds_bucket.json.gz.
# Data for storage_operation_duration_seconds_count has been saved to ./data/storage_operation_duration_seconds_count.json.gz.
# Data for storage_operation_duration_seconds_sum has been saved to ./data/storage_operation_duration_seconds_sum.json.gz.
# Data for up has been saved to ./data/up.json.gz.
# Data for volume_manager_selinux_container_errors_total has been saved to ./data/volume_manager_selinux_container_errors_total.json.gz.
# Data for volume_manager_selinux_container_warnings_total has been saved to ./data/volume_manager_selinux_container_warnings_total.json.gz.
# Data for volume_manager_selinux_pod_context_mismatch_errors_total has been saved to ./data/volume_manager_selinux_pod_context_mismatch_errors_total.json.gz.
# Data for volume_manager_selinux_pod_context_mismatch_warnings_total has been saved to ./data/volume_manager_selinux_pod_context_mismatch_warnings_total.json.gz.
# Data for volume_manager_total_volumes has been saved to ./data/volume_manager_total_volumes.json.gz.
# Data for volume_operation_total_seconds_bucket has been saved to ./data/volume_operation_total_seconds_bucket.json.gz.
# Data for volume_operation_total_seconds_count has been saved to ./data/volume_operation_total_seconds_count.json.gz.
# Data for volume_operation_total_seconds_sum has been saved to ./data/volume_operation_total_seconds_sum.json.gz.
# Data for watch_cache_capacity has been saved to ./data/watch_cache_capacity.json.gz.
# Data for watch_cache_capacity_increase_total has been saved to ./data/watch_cache_capacity_increase_total.json.gz.
# Data for workqueue_adds_total has been saved to ./data/workqueue_adds_total.json.gz.
# Data for workqueue_depth has been saved to ./data/workqueue_depth.json.gz.
# Data for workqueue_longest_running_processor_seconds has been saved to ./data/workqueue_longest_running_processor_seconds.json.gz.
# Data for workqueue_queue_duration_seconds_bucket has been saved to ./data/workqueue_queue_duration_seconds_bucket.json.gz.
# Data for workqueue_queue_duration_seconds_count has been saved to ./data/workqueue_queue_duration_seconds_count.json.gz.
# Data for workqueue_queue_duration_seconds_sum has been saved to ./data/workqueue_queue_duration_seconds_sum.json.gz.
# Data for workqueue_retries_total has been saved to ./data/workqueue_retries_total.json.gz.
# Data for workqueue_unfinished_work_seconds has been saved to ./data/workqueue_unfinished_work_seconds.json.gz.
# Data for workqueue_work_duration_seconds_bucket has been saved to ./data/workqueue_work_duration_seconds_bucket.json.gz.
# Data for workqueue_work_duration_seconds_count has been saved to ./data/workqueue_work_duration_seconds_count.json.gz.
# Data for workqueue_work_duration_seconds_sum has been saved to ./data/workqueue_work_duration_seconds_sum.json.gz.
